# %%
# Import libraries
import pandas as pd
from pandas import DataFrame
from pathlib import Path
import numpy as np
import seaborn as sns
from scipy.sparse import csr_matrix
from sklearn.neighbors import NearestNeighbors
import ast
import random
from pathlib import Path

# %%
def extract_id(obj):
    try:
        if isinstance(obj, str):
            if not obj.strip().startswith('{'):
                return str(obj)
            _dict = ast.literal_eval(obj)
            return _dict.get('id')
        elif isinstance(obj, dict):
            return obj.get('id')
        return str(obj) if obj is not None else None
    except:
        return None

def convert_object_to_string(df):
    object_columns = df.select_dtypes(include=['object']).columns
    df[object_columns] = df[object_columns].astype('string')
    return df

def process_df(df):
    object_columns = df.select_dtypes(include=['object']).columns
    print(object_columns)
    df[object_columns] = df[object_columns].map(extract_id)
    # df = convert_object_to_string(df)
    return df

# %%
import os
def c_path(path, output_folder="data"):
    return Path(output_folder, path)

order_path = c_path('order.csv')
restaurant_path = c_path('restaurant.csv')
dish_category = c_path('dish_category.csv')
dish_review_path = c_path('dish_review.csv')

user_path = c_path('user.csv')
profile_path = c_path('profile.csv')
dish_path = c_path('dish.csv')

# import os
# from django.conf import settings
# def c_path(path, output_folder="data"):
#     return Path(output_folder, path)

# order_path = os.path.join(settings.BASE_DIR, 'w_rc_sys', 'data','order.csv')
# restaurant_path = os.path.join(settings.BASE_DIR, 'w_rc_sys', 'data','restaurant.csv')
# dish_category = os.path.join(settings.BASE_DIR, 'w_rc_sys', 'data','dish_category.csv')
# dish_review_path = os.path.join(settings.BASE_DIR, 'w_rc_sys', 'data','dish_review.csv')

# user_path = os.path.join(settings.BASE_DIR, 'w_rc_sys', 'data','user.csv')
# profile_path = os.path.join(settings.BASE_DIR, 'w_rc_sys', 'data','profile.csv')
# dish_path = os.path.join(settings.BASE_DIR, 'w_rc_sys', 'data','dish.csv')

# %%
order_df = pd.read_csv(order_path, index_col=0)
order_df = process_df(order_df)

profile_df = pd.read_csv(profile_path, index_col=0)
profile_df = process_df(profile_df)

restaurant_df = pd.read_csv(restaurant_path, index_col=0)
restaurant_df = process_df(restaurant_df)

dish_category_df = pd.read_csv(dish_category, index_col=0)
dish_category_df = process_df(dish_category_df)

dish_review_df = pd.read_csv(dish_review_path, index_col=0)
dish_review_df = process_df(dish_review_df)

user_df = pd.read_csv(user_path, index_col=0)
user_df = process_df(user_df)

dish_df = pd.read_csv(dish_path, index_col=0)
dish_df = process_df(dish_df)
# Out:
# Index(['cart', 'user', 'delivery', 'delivery_address', 'payment_method',
#        'status', 'created_at'],
#       dtype='object')
# Index(['user', 'name', 'avatar', 'gender', 'date_of_birth'], dtype='object')
# Index(['basic_info', 'dishes'], dtype='object')
# Index(['name', 'description', 'created_at', 'updated_at', 'image'], dtype='object')
# Index(['user', 'title', 'content', 'created_at', 'updated_at', 'order',
#        'images', 'dish', 'replies'],
#       dtype='object')
# Index(['name', 'avatar'], dtype='object')
# Index(['name', 'image', 'description', 'category', 'images', 'restaurant'], dtype='object')

# %%
dish_review_df = process_df(dish_review_df)
dish_review_df
# Out:
# Index(['user', 'title', 'content', 'created_at', 'updated_at', 'order',
#        'images', 'dish', 'replies'],
#       dtype='object')
#                                                                       user  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9  8d8373c7-8c4d-4906-b059-d21ba15c7fa0
# 5407cb97-4721-4ee0-8d24-0adc17d728a9  8d8373c7-8c4d-4906-b059-d21ba15c7fa0
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b  8d8373c7-8c4d-4906-b059-d21ba15c7fa0
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5  8d8373c7-8c4d-4906-b059-d21ba15c7fa0
# 9376d0cc-fbc0-421f-8016-3e404b64d966  8d8373c7-8c4d-4906-b059-d21ba15c7fa0
# ...                                                                    ...
# 73ffec58-1cc2-46ab-8848-cfd4ab8a05e5  8a4cd432-e00d-4418-b144-3650b0d9c033
# 4b539343-e418-4e52-9fe1-4404a64c38e6  8a4cd432-e00d-4418-b144-3650b0d9c033
# d1f31c6c-47d9-4174-bdb0-16a3279e9071  8a4cd432-e00d-4418-b144-3650b0d9c033
# 35bd05e3-04ee-4d2c-b4c6-f795f6407b88  8a4cd432-e00d-4418-b144-3650b0d9c033
# 54f6d3ec-542c-4627-8304-5078a1c04e39  8a4cd432-e00d-4418-b144-3650b0d9c033
#
#                                       rating  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9       4
# 5407cb97-4721-4ee0-8d24-0adc17d728a9       3
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b       3
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5       5
# 9376d0cc-fbc0-421f-8016-3e404b64d966       3
# ...                                      ...
# 73ffec58-1cc2-46ab-8848-cfd4ab8a05e5       3
# 4b539343-e418-4e52-9fe1-4404a64c38e6       5
# d1f31c6c-47d9-4174-bdb0-16a3279e9071       5
# 35bd05e3-04ee-4d2c-b4c6-f795f6407b88       2
# 54f6d3ec-542c-4627-8304-5078a1c04e39       5
#
#                                                                                   title  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9                       Rule try general cover baby.
# 5407cb97-4721-4ee0-8d24-0adc17d728a9     Relate later Congress know school watch event.
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b                              Rock quality article.
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5                     Offer official part now close.
# 9376d0cc-fbc0-421f-8016-3e404b64d966            Attorney pull serious plan environment.
# ...                                                                                 ...
# 73ffec58-1cc2-46ab-8848-cfd4ab8a05e5            Another they no direction reflect hand.
# 4b539343-e418-4e52-9fe1-4404a64c38e6                    Public woman successful myself.
# d1f31c6c-47d9-4174-bdb0-16a3279e9071  South responsibility forget us degree prevent ...
# 35bd05e3-04ee-4d2c-b4c6-f795f6407b88                         International leader will.
# 54f6d3ec-542c-4627-8304-5078a1c04e39      Item opportunity hotel parent country worker.
#
#                                                                                 content  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9  West majority interview none available produce...
# 5407cb97-4721-4ee0-8d24-0adc17d728a9  Part start fire job fall. Indicate them same w...
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b  Own mention current. Task wait along yes. Any ...
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5  Every bank during type catch court. Kitchen ar...
# 9376d0cc-fbc0-421f-8016-3e404b64d966  Example exist wait mission simple conference e...
# ...                                                                                 ...
# 73ffec58-1cc2-46ab-8848-cfd4ab8a05e5  Beyond market white technology speak. Alone ar...
# 4b539343-e418-4e52-9fe1-4404a64c38e6  Ahead challenge produce figure sit yourself. D...
# d1f31c6c-47d9-4174-bdb0-16a3279e9071  Walk wear station candidate data by our. Seem ...
# 35bd05e3-04ee-4d2c-b4c6-f795f6407b88  Finish skill many. Everybody force step upon. ...
# 54f6d3ec-542c-4627-8304-5078a1c04e39  Visit prove of response seem window moment. Ef...
#
#                                                             created_at  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9  2024-11-17T00:52:17.808880+07:00
# 5407cb97-4721-4ee0-8d24-0adc17d728a9  2024-11-17T00:52:17.792757+07:00
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b  2024-11-17T00:52:17.787104+07:00
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5  2024-11-17T00:52:17.774806+07:00
# 9376d0cc-fbc0-421f-8016-3e404b64d966  2024-11-17T00:52:17.758991+07:00
# ...                                                                ...
# 73ffec58-1cc2-46ab-8848-cfd4ab8a05e5  2024-11-17T00:43:33.614380+07:00
# 4b539343-e418-4e52-9fe1-4404a64c38e6  2024-11-17T00:43:33.607667+07:00
# d1f31c6c-47d9-4174-bdb0-16a3279e9071  2024-11-17T00:43:33.586577+07:00
# 35bd05e3-04ee-4d2c-b4c6-f795f6407b88  2024-11-17T00:43:33.566773+07:00
# 54f6d3ec-542c-4627-8304-5078a1c04e39  2024-11-17T00:43:33.488568+07:00
#
#                                                             updated_at  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9  2024-11-17T00:52:17.808880+07:00
# 5407cb97-4721-4ee0-8d24-0adc17d728a9  2024-11-17T00:52:17.792757+07:00
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b  2024-11-17T00:52:17.787104+07:00
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5  2024-11-17T00:52:17.774806+07:00
# 9376d0cc-fbc0-421f-8016-3e404b64d966  2024-11-17T00:52:17.758991+07:00
# ...                                                                ...
# 73ffec58-1cc2-46ab-8848-cfd4ab8a05e5  2024-11-17T00:43:33.614380+07:00
# 4b539343-e418-4e52-9fe1-4404a64c38e6  2024-11-17T00:43:33.607667+07:00
# d1f31c6c-47d9-4174-bdb0-16a3279e9071  2024-11-17T00:43:33.586577+07:00
# 35bd05e3-04ee-4d2c-b4c6-f795f6407b88  2024-11-17T00:43:33.566773+07:00
# 54f6d3ec-542c-4627-8304-5078a1c04e39  2024-11-17T00:43:33.488568+07:00
#
#                                                                      order  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9  dbd46d6d-c7aa-4145-bee0-54ae09712791
# 5407cb97-4721-4ee0-8d24-0adc17d728a9  dbd46d6d-c7aa-4145-bee0-54ae09712791
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b  dbd46d6d-c7aa-4145-bee0-54ae09712791
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5  dbd46d6d-c7aa-4145-bee0-54ae09712791
# 9376d0cc-fbc0-421f-8016-3e404b64d966  dbd46d6d-c7aa-4145-bee0-54ae09712791
# ...                                                                    ...
# 73ffec58-1cc2-46ab-8848-cfd4ab8a05e5  0980f960-6cde-4f59-8dd5-4c21b1055665
# 4b539343-e418-4e52-9fe1-4404a64c38e6  0980f960-6cde-4f59-8dd5-4c21b1055665
# d1f31c6c-47d9-4174-bdb0-16a3279e9071  0980f960-6cde-4f59-8dd5-4c21b1055665
# 35bd05e3-04ee-4d2c-b4c6-f795f6407b88  0980f960-6cde-4f59-8dd5-4c21b1055665
# 54f6d3ec-542c-4627-8304-5078a1c04e39  0980f960-6cde-4f59-8dd5-4c21b1055665
#
#                                       total_likes  total_replies  is_liked  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9            0              0     False
# 5407cb97-4721-4ee0-8d24-0adc17d728a9            0              0     False
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b            0              0     False
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5            0              0     False
# 9376d0cc-fbc0-421f-8016-3e404b64d966            0              0     False
# ...                                           ...            ...       ...
# 73ffec58-1cc2-46ab-8848-cfd4ab8a05e5            0              0     False
# 4b539343-e418-4e52-9fe1-4404a64c38e6            0              0     False
# d1f31c6c-47d9-4174-bdb0-16a3279e9071            0              0     False
# 35bd05e3-04ee-4d2c-b4c6-f795f6407b88            0              0     False
# 54f6d3ec-542c-4627-8304-5078a1c04e39            0              0     False
#
#                                      images  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9     []
# 5407cb97-4721-4ee0-8d24-0adc17d728a9     []
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b     []
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5     []
# 9376d0cc-fbc0-421f-8016-3e404b64d966     []
# ...                                     ...
# 73ffec58-1cc2-46ab-8848-cfd4ab8a05e5     []
# 4b539343-e418-4e52-9fe1-4404a64c38e6     []
# d1f31c6c-47d9-4174-bdb0-16a3279e9071     []
# 35bd05e3-04ee-4d2c-b4c6-f795f6407b88     []
# 54f6d3ec-542c-4627-8304-5078a1c04e39     []
#
#                                                                       dish  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9  d0604c70-9682-4844-a8a3-6b023ef7e3a9
# 5407cb97-4721-4ee0-8d24-0adc17d728a9  a2575c57-bf35-4101-9898-9f6effca4c81
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b  9ebf4de7-137e-46a2-bf72-c01ac9bad90c
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5  95ccb242-0384-4d2a-94c1-611b8e49f020
# 9376d0cc-fbc0-421f-8016-3e404b64d966  904c5634-1eaa-4599-9747-f559367d9c11
# ...                                                                    ...
# 73ffec58-1cc2-46ab-8848-cfd4ab8a05e5  8f91bf7c-8fde-43b2-88a4-ac2e2cb7c1fe
# 4b539343-e418-4e52-9fe1-4404a64c38e6  7f57cf5c-ea27-4921-ba5c-a1322705097e
# d1f31c6c-47d9-4174-bdb0-16a3279e9071  6bec8d7e-fd03-4365-b7f1-a7a6978c1fce
# 35bd05e3-04ee-4d2c-b4c6-f795f6407b88  20ae1422-f4f3-4519-b3a1-9f041d5f87e5
# 54f6d3ec-542c-4627-8304-5078a1c04e39  10f84de3-f505-4937-9098-ed06457e09c4
#
#                                      replies
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9      []
# 5407cb97-4721-4ee0-8d24-0adc17d728a9      []
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b      []
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5      []
# 9376d0cc-fbc0-421f-8016-3e404b64d966      []
# ...                                      ...
# 73ffec58-1cc2-46ab-8848-cfd4ab8a05e5      []
# 4b539343-e418-4e52-9fe1-4404a64c38e6      []
# d1f31c6c-47d9-4174-bdb0-16a3279e9071      []
# 35bd05e3-04ee-4d2c-b4c6-f795f6407b88      []
# 54f6d3ec-542c-4627-8304-5078a1c04e39      []
#
# [34476 rows x 13 columns]

# %%
dish_review_df.head()
# Out:
#                                                                       user  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9  8d8373c7-8c4d-4906-b059-d21ba15c7fa0
# 5407cb97-4721-4ee0-8d24-0adc17d728a9  8d8373c7-8c4d-4906-b059-d21ba15c7fa0
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b  8d8373c7-8c4d-4906-b059-d21ba15c7fa0
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5  8d8373c7-8c4d-4906-b059-d21ba15c7fa0
# 9376d0cc-fbc0-421f-8016-3e404b64d966  8d8373c7-8c4d-4906-b059-d21ba15c7fa0
#
#                                       rating  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9       4
# 5407cb97-4721-4ee0-8d24-0adc17d728a9       3
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b       3
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5       5
# 9376d0cc-fbc0-421f-8016-3e404b64d966       3
#
#                                                                                title  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9                    Rule try general cover baby.
# 5407cb97-4721-4ee0-8d24-0adc17d728a9  Relate later Congress know school watch event.
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b                           Rock quality article.
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5                  Offer official part now close.
# 9376d0cc-fbc0-421f-8016-3e404b64d966         Attorney pull serious plan environment.
#
#                                                                                 content  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9  West majority interview none available produce...
# 5407cb97-4721-4ee0-8d24-0adc17d728a9  Part start fire job fall. Indicate them same w...
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b  Own mention current. Task wait along yes. Any ...
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5  Every bank during type catch court. Kitchen ar...
# 9376d0cc-fbc0-421f-8016-3e404b64d966  Example exist wait mission simple conference e...
#
#                                                             created_at  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9  2024-11-17T00:52:17.808880+07:00
# 5407cb97-4721-4ee0-8d24-0adc17d728a9  2024-11-17T00:52:17.792757+07:00
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b  2024-11-17T00:52:17.787104+07:00
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5  2024-11-17T00:52:17.774806+07:00
# 9376d0cc-fbc0-421f-8016-3e404b64d966  2024-11-17T00:52:17.758991+07:00
#
#                                                             updated_at  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9  2024-11-17T00:52:17.808880+07:00
# 5407cb97-4721-4ee0-8d24-0adc17d728a9  2024-11-17T00:52:17.792757+07:00
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b  2024-11-17T00:52:17.787104+07:00
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5  2024-11-17T00:52:17.774806+07:00
# 9376d0cc-fbc0-421f-8016-3e404b64d966  2024-11-17T00:52:17.758991+07:00
#
#                                                                      order  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9  dbd46d6d-c7aa-4145-bee0-54ae09712791
# 5407cb97-4721-4ee0-8d24-0adc17d728a9  dbd46d6d-c7aa-4145-bee0-54ae09712791
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b  dbd46d6d-c7aa-4145-bee0-54ae09712791
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5  dbd46d6d-c7aa-4145-bee0-54ae09712791
# 9376d0cc-fbc0-421f-8016-3e404b64d966  dbd46d6d-c7aa-4145-bee0-54ae09712791
#
#                                       total_likes  total_replies  is_liked  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9            0              0     False
# 5407cb97-4721-4ee0-8d24-0adc17d728a9            0              0     False
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b            0              0     False
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5            0              0     False
# 9376d0cc-fbc0-421f-8016-3e404b64d966            0              0     False
#
#                                      images  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9     []
# 5407cb97-4721-4ee0-8d24-0adc17d728a9     []
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b     []
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5     []
# 9376d0cc-fbc0-421f-8016-3e404b64d966     []
#
#                                                                       dish  \
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9  d0604c70-9682-4844-a8a3-6b023ef7e3a9
# 5407cb97-4721-4ee0-8d24-0adc17d728a9  a2575c57-bf35-4101-9898-9f6effca4c81
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b  9ebf4de7-137e-46a2-bf72-c01ac9bad90c
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5  95ccb242-0384-4d2a-94c1-611b8e49f020
# 9376d0cc-fbc0-421f-8016-3e404b64d966  904c5634-1eaa-4599-9747-f559367d9c11
#
#                                      replies
# id
# 93ca94ea-ce7c-4433-91f4-842d50eb34f9      []
# 5407cb97-4721-4ee0-8d24-0adc17d728a9      []
# 2af626f3-79c3-4ea5-9d19-34dccdcf5a4b      []
# 87f9b306-f401-496c-9ba4-df5b0d9ba0a5      []
# 9376d0cc-fbc0-421f-8016-3e404b64d966      []

# %%
dish_df = pd.read_csv(dish_path, index_col=0)
dish_df.drop(dish_df.iloc[:, 7:], inplace=True, axis=1)
dish_df.drop(columns=['image', 'description', 'rating', 'category'], inplace=True)
dish_df.head()
# Out:
#                                                       name  original_price  \
# id
# 0003d998-e2bf-4bab-89e5-ae2f009533ff  Pho protect official           98.63
# 000e5ebc-1d00-43dd-b7ec-a27e30c87653  Rice health standard           29.39
# 004cbebb-5e78-4174-92b4-8dc8e3ef2be5      Pizza tax letter           15.86
# 006c16e6-b7e7-45a2-8bb9-6accd930e217         Pasta east my           78.24
# 007cd656-a676-4428-aa6b-9eff964a16c3   Goi Cuon apply wear           30.11
#
#                                       discount_price
# id
# 0003d998-e2bf-4bab-89e5-ae2f009533ff           12.18
# 000e5ebc-1d00-43dd-b7ec-a27e30c87653            9.86
# 004cbebb-5e78-4174-92b4-8dc8e3ef2be5           33.59
# 006c16e6-b7e7-45a2-8bb9-6accd930e217           12.67
# 007cd656-a676-4428-aa6b-9eff964a16c3           14.65

# %%
# user_df = pd.read_csv(user_path, index_col=0)
# profile_df = pd.read_csv(profile_path, index_col=0)


# user_df = pd.merge(user_df, profile_df, left_on='id', right_on='user')

# try:
#     user_df.drop(columns=[
#         'deliverer',
#         'restaurant',
#         'is_active',
#         'is_staff',
#         'is_certified_deliverer', 
#         'is_certified_restaurant', 
#         'selected_location',
#     ], inplace=True)
# except:
#     print("Columns specified do not exist")

user_df.head()
# Out:
#                                                 name  phone_number  \
# id
# 006835c2-c145-41b0-9f49-299376103a09  Jonathan Allen   84443090045
# 014d5bb0-701f-4343-ba83-6a3f5821ba46     Andrea Mann   84971484792
# 016846cd-060c-43ef-a26b-057387fb69b4  Raymond Miller   84439281346
# 01922013-4f06-4e8e-9f22-a5bbe84a5056   Terry Shaffer   84413259384
# 01b9dbf3-c6d3-47d3-a2dd-3af3bf3cc88a     Kelli Henry   84371189161
#
#                                                                                  avatar
# id
# 006835c2-c145-41b0-9f49-299376103a09  http://127.0.0.1:8000/images/avatar/user/avata...
# 014d5bb0-701f-4343-ba83-6a3f5821ba46  http://127.0.0.1:8000/images/avatar/user/avata...
# 016846cd-060c-43ef-a26b-057387fb69b4  http://127.0.0.1:8000/images/avatar/user/avata...
# 01922013-4f06-4e8e-9f22-a5bbe84a5056  http://127.0.0.1:8000/images/avatar/user/avata...
# 01b9dbf3-c6d3-47d3-a2dd-3af3bf3cc88a  http://127.0.0.1:8000/images/avatar/user/avata...

# %%
user_dish_review_df = pd.merge(user_df, dish_review_df, left_on='id', right_on='user')

# %%
user_dish_review_df.head()
# Out:
#              name  phone_number  \
# 0  Jonathan Allen   84443090045
# 1  Jonathan Allen   84443090045
# 2  Jonathan Allen   84443090045
# 3  Jonathan Allen   84443090045
# 4  Jonathan Allen   84443090045
#
#                                               avatar  \
# 0  http://127.0.0.1:8000/images/avatar/user/avata...
# 1  http://127.0.0.1:8000/images/avatar/user/avata...
# 2  http://127.0.0.1:8000/images/avatar/user/avata...
# 3  http://127.0.0.1:8000/images/avatar/user/avata...
# 4  http://127.0.0.1:8000/images/avatar/user/avata...
#
#                                    user  rating  \
# 0  006835c2-c145-41b0-9f49-299376103a09       2
# 1  006835c2-c145-41b0-9f49-299376103a09       2
# 2  006835c2-c145-41b0-9f49-299376103a09       2
# 3  006835c2-c145-41b0-9f49-299376103a09       5
# 4  006835c2-c145-41b0-9f49-299376103a09       4
#
#                                                title  \
# 0  Choose need improve class team who control piece.
# 1                       Federal different itself of.
# 2                               Board radio quickly.
# 3       Animal say book mother manager travel state.
# 4  Together compare accept race wind answer between.
#
#                                              content  \
# 0  Form win purpose billion high. Special fact ru...
# 1  Central account she lot line training PM coach...
# 2  Discuss community first subject talk. Develop ...
# 3  Hear individual growth ground leader forward t...
# 4  Information then TV plant claim interview. Med...
#
#                          created_at                        updated_at  \
# 0  2024-11-17T00:51:40.627014+07:00  2024-11-17T00:51:40.627014+07:00
# 1  2024-11-17T00:51:40.625980+07:00  2024-11-17T00:51:40.625980+07:00
# 2  2024-11-17T00:51:40.610352+07:00  2024-11-17T00:51:40.610352+07:00
# 3  2024-11-17T00:51:40.590362+07:00  2024-11-17T00:51:40.590362+07:00
# 4  2024-11-17T00:48:25.713116+07:00  2024-11-17T00:48:25.713116+07:00
#
#                                   order  total_likes  total_replies  is_liked  \
# 0  b44478d2-2451-4023-9d85-062a64262b5a            0              0     False
# 1  b44478d2-2451-4023-9d85-062a64262b5a            0              0     False
# 2  b44478d2-2451-4023-9d85-062a64262b5a            0              0     False
# 3  b44478d2-2451-4023-9d85-062a64262b5a            0              0     False
# 4  273a1b97-6096-4628-8998-917e7c913312            0              0     False
#
#   images                                  dish replies
# 0     []  f238becb-7149-47bb-8d4d-ede23a3a1eca      []
# 1     []  f07a7ae8-522b-489c-8fb9-d2e83012f3c1      []
# 2     []  370d5946-2e4b-4881-ae7c-a02bb2ec215b      []
# 3     []  1ee45969-ef1c-46aa-b290-a3096c824de0      []
# 4     []  f238becb-7149-47bb-8d4d-ede23a3a1eca      []

# %%
dish_user_review_df = pd.merge(user_dish_review_df, dish_df, left_on='dish', right_on='id')

# %%
dish_user_review_df.rename(columns={'name_x': 'user_name', 'name_y': 'dish_name'}, inplace=True)
dish_user_review_df.drop(columns=[
    # 'user_name', 
    # 'dish_name',
    # 'user', 
    # 'order', 
    # 'dish',
    # 'rating', 
    'phone_number', 
    'avatar', 
    'title',
    'content', 
    'created_at', 
    'updated_at', 
    'total_likes',
    'total_replies',
    'is_liked',
    'images',
    'replies',
    'original_price',
    'discount_price'
], inplace=True)

# %%
dish_user_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34394 entries, 0 to 34393
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   user_name  34394 non-null  object
#  1   user       34394 non-null  object
#  2   rating     34394 non-null  int64
#  3   order      34394 non-null  object
#  4   dish       34394 non-null  object
#  5   dish_name  34394 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 1.6+ MB

# %%
dish_user_review_df.shape
# Out:
# (34394, 6)

# %%
user_df.head()
# Out:
#                                                 name  phone_number  \
# id
# 006835c2-c145-41b0-9f49-299376103a09  Jonathan Allen   84443090045
# 014d5bb0-701f-4343-ba83-6a3f5821ba46     Andrea Mann   84971484792
# 016846cd-060c-43ef-a26b-057387fb69b4  Raymond Miller   84439281346
# 01922013-4f06-4e8e-9f22-a5bbe84a5056   Terry Shaffer   84413259384
# 01b9dbf3-c6d3-47d3-a2dd-3af3bf3cc88a     Kelli Henry   84371189161
#
#                                                                                  avatar
# id
# 006835c2-c145-41b0-9f49-299376103a09  http://127.0.0.1:8000/images/avatar/user/avata...
# 014d5bb0-701f-4343-ba83-6a3f5821ba46  http://127.0.0.1:8000/images/avatar/user/avata...
# 016846cd-060c-43ef-a26b-057387fb69b4  http://127.0.0.1:8000/images/avatar/user/avata...
# 01922013-4f06-4e8e-9f22-a5bbe84a5056  http://127.0.0.1:8000/images/avatar/user/avata...
# 01b9dbf3-c6d3-47d3-a2dd-3af3bf3cc88a  http://127.0.0.1:8000/images/avatar/user/avata...

# %%
from scipy.sparse import csr_matrix

def create_matrix(df):
    N = len(df['user'].unique())
    M = len(df['dish'].unique())
      
    user_mapper = dict(zip(np.unique(df["user"]), list(range(N))))
    dish_mapper = dict(zip(np.unique(df["dish"]), list(range(M))))
      
    user_inv_mapper = dict(zip(list(range(N)), np.unique(df["user"])))
    dish_inv_mapper = dict(zip(list(range(M)), np.unique(df["dish"])))
      
    user_index = [user_mapper[i] for i in df['user']]
    dish_index = [dish_mapper[i] for i in df['dish']]
  
    X = csr_matrix((df["rating"].values, (dish_index, user_index)), 
                    shape=(M, N))      
    return X, user_mapper, dish_mapper, user_inv_mapper, dish_inv_mapper

# %%
X, user_mapper, dish_mapper, user_inv_mapper, dish_inv_mapper = create_matrix(dish_user_review_df)

# %% [markdown]
# # K-Nearest Neighbors
#
# Sci-kit Learn's NearestNeighbors algorithm is an unsupervised learner for implementing neighbor searches. Here we will execute a brute search with a cosine similarity matrix where the algorithm normalizes the rating by subtracting the mean.

# %%
from sklearn.neighbors import NearestNeighbors

model = NearestNeighbors(n_neighbors=5, algorithm="brute", metric='cosine')
model.fit(X)
# Out:
# NearestNeighbors(algorithm='brute', metric='cosine')

# %%
dish_names = dict(zip(dish_user_review_df['dish'], dish_user_review_df['dish_name']))
# dish_names

# %%
dish_names_inv = {v: k for k, v in dish_names.items()}
# dish_mapper
dish_names
# len(dish_names_inv)
# Out:
# {'f238becb-7149-47bb-8d4d-ede23a3a1eca': 'Takoyaki development impact',
#  'f07a7ae8-522b-489c-8fb9-d2e83012f3c1': 'Banh Mi ahead hour',
#  '370d5946-2e4b-4881-ae7c-a02bb2ec215b': 'Pho peace data',
#  '1ee45969-ef1c-46aa-b290-a3096c824de0': 'Rice not me',
#  'c325b30c-98ce-4810-90ac-ad4eb977dadb': 'Sandwich many prove',
#  'a302ed97-29e4-46c9-94c4-325d45b66de7': 'Takoyaki data become',
#  '6f15d798-6b6d-41b7-b40f-311caa1d0779': 'Donut themselves land',
#  '3ddf8a3d-878d-4dc5-a41f-ce040869d703': 'Salad game politics',
#  '28f2fe36-f5db-4d60-ab37-2b97ff0b9607': 'Salad rest international',
#  '19117c66-4b07-4fff-9d33-27c3206f14a4': 'Pudding behavior simply',
#  'd3c0dab2-9862-4206-9bae-5f9099946fb5': 'Taco benefit apply',
#  'cd205ea6-69b2-45ee-b244-eba2d45d5198': 'Dumpling age church',
#  '4e68a925-612d-4551-a04c-1fa9975256a1': 'Rice serve former',
#  '4c8dffca-b4fd-4d25-a358-7a9946f1c4c0': 'Banh Mi yes ever',
#  '3157a0e0-02cb-4aa8-b22a-4198902ad84c': 'Burrito prepare night',
#  '03f2ebfd-24b3-445d-84af-3d5d771de102': 'Pudding cover prevent',
#  '8372b4d6-bf25-4ea4-910e-4665f0ea5ff4': 'Donut should budget',
#  '4560b47f-8ee6-4fa5-b6f8-636162777a56': 'Salad all a',
#  'fa0bb4f5-feb2-423b-8e95-5b9d90de2dee': 'Rice three business',
#  'f07bd2b1-07d9-4e42-a3a3-1f96ed0bc816': 'Ice Cream talk sea',
#  '8e7c82d7-5a74-4dd8-9faa-ccfd95882011': 'Salad set light',
#  'ef5488c8-4cd4-403e-bb28-b93382ad875e': 'Banh Mi important light',
#  '44163943-adf8-4932-9e0a-159e35123f53': 'Cookie road benefit',
#  '3e8964b5-b53f-4776-9880-f51df7116830': 'Hot Dog road avoid',
#  '2f4656ce-5367-4153-837c-34026fbe2e3e': 'Burger fire serve',
#  '26d98675-d791-41ef-9b32-bbe1a446d10f': 'Dumpling officer but',
#  '22426c21-7919-4bc6-ac1f-8f0fa60970bb': 'Pho no purpose',
#  '203a7810-5814-45d6-8631-b46abf39cf44': 'Goi Cuon effect measure',
#  '1285f2bc-29c4-4dde-bbe2-8713da452ca6': 'Burrito site doctor',
#  '0d88ae3c-9a50-4038-a964-b1baf7e8767d': 'Banh Mi someone only',
#  'dfe1ce7d-3204-4942-a132-dd184e5710d3': 'Pho know so',
#  'd9bdf6a4-7198-4afa-a583-29b3f8afbd9e': 'Banh Mi hard sometimes',
#  'c0c760ad-30d2-407b-b2ce-8ebdea5824df': 'Hot Dog phone parent',
#  'a104deef-8a64-46fc-b4cc-c1c5cc054628': 'Goi Cuon herself time',
#  '56fa33c3-4f05-4b73-8f17-a30720d4faa5': 'Ice Cream ever life',
#  '3724e660-2741-45c8-a6f5-d0ae3e7fb54f': 'Takoyaki avoid billion',
#  '37f5b3fb-a92e-434f-9755-62aa6637dcad': 'Banh Mi book practice',
#  '35729092-ce71-44d5-8aee-70ad6a34eb0c': 'Taco style role',
#  '1b629869-2a75-4462-95d7-46020d1be557': 'Burrito hold heart',
#  '18648eed-4dab-4db8-a0a2-6718f494a30d': 'Taco important end',
#  '0be2fe05-427b-4f79-a7dc-e2c1f0923040': 'Ice Cream perform large',
#  '04120a05-f73e-4ee0-a8d7-48bcb0e53323': 'Ice Cream to page',
#  'e3ea4b32-7685-4957-91bc-3868bc6d4a27': 'Pasta produce together',
#  'be53f16d-92a7-4470-ae15-f0769e78620b': 'Taco response parent',
#  '5d0afd50-b0aa-48a4-bc2c-773e7820532a': 'Cookie positive agent',
#  'e2e3efba-3c09-4fb8-bcf2-49c8f1481814': 'Pasta management read',
#  'cd3f3349-3bc0-46b9-9e61-4bf6597c9191': 'Taco when very',
#  'b57ce414-628a-4230-948c-b22a2e9379b7': 'Donut themselves green',
#  '9c75f3cb-375a-4e9a-af9e-d023cde9134f': 'Dumpling religious guy',
#  'b32793d5-b981-4b4c-8c98-86e25f4b6bd1': 'Salad something argue',
#  '97e7bb27-0e8d-49fa-b252-f3c2c3f383c1': 'Dumpling kitchen recent',
#  '96b8a8c2-45ba-4fa8-9187-7857d63fa9f0': 'Takoyaki matter yet',
#  '95d655af-c772-474e-84aa-2d3e4549ba5e': 'Burrito animal indeed',
#  '9515942b-ad47-4c38-a179-7ece301b25f8': 'Goi Cuon no center',
#  '84399554-ca77-49c9-ae50-1c597b2c4011': 'Rice range doctor',
#  '80426ef4-942a-40ac-896e-d6323020beab': 'Cookie fine listen',
#  '7b583bae-fe4c-44eb-8e4c-521603fe8f34': 'Pasta account this',
#  '5506960f-5ec5-4c54-99cf-753d84ad798f': 'Hot Dog against difference',
#  '678a34cb-d5c8-4921-8e19-e81d6d8bb968': 'Ice Cream back see',
#  '4ad84bf1-25fd-4acb-93e1-b2ee944127a4': 'Hot Dog share them',
#  '49860d5d-82e6-43eb-8ede-3a87fb5f7ee0': 'Pasta fish space',
#  '06d3c62d-2f45-4491-83ee-c9b8d16ad0ea': 'Ice Cream city imagine',
#  'd0f136ca-5e20-4711-9693-8f3bf45a4dd8': 'Hot Dog sort or',
#  'c388ac45-d131-474e-97af-cdd47827b8e3': 'Banh Mi final call',
#  'c3406f18-3e78-4f59-869a-c9841fc7059f': 'Taco thank on',
#  '6825b953-7072-491f-be52-927c77677466': 'Burger although hundred',
#  'ec75d733-ef40-4575-aa56-83d4a43e5a9b': 'Burrito listen appear',
#  'b836e75b-1103-476f-926f-03ecdd65310c': 'Takoyaki education so',
#  'd87ef748-0ac0-44fd-bbdc-f01ca4f1493a': 'Salad five positive',
#  'ac4ebf8d-ad35-4c4e-8544-069825ba9390': 'Pudding try include',
#  'a011af93-6880-4bfb-8e81-23f84db5b7a0': 'Pho business customer',
#  'a0fe6536-faca-4f00-bcb4-4c0319fe3475': 'Sandwich service thank',
#  '8b6f5ea4-ecb4-4b09-8815-bfab308c7de7': 'Rice off scene',
#  '6b5b403a-b5ea-4548-8565-262382ddd41f': 'Burger at would',
#  '3b5d191e-74d6-4c4e-a04f-6b83ae594ed3': 'Ice Cream front last',
#  '5fa868e8-71bf-4100-aaf5-6783272fca1c': 'Sandwich candidate discover',
#  '3396c037-8c09-40ec-8e0f-b08359136630': 'Pasta budget thousand',
#  '1e7bc4d4-4476-43de-9aa9-97cc9a53165a': 'Banh Mi positive herself',
#  '004cbebb-5e78-4174-92b4-8dc8e3ef2be5': 'Pizza tax letter',
#  'f2b23f05-565a-42f1-9ad4-69712ddf0897': 'Pho treat reason',
#  'e193b381-f25e-495a-bfcf-2c2b1d7cad3c': 'Hot Dog follow first',
#  'd55000b2-3de4-416e-9be7-792fd62444b0': 'Rice share end',
#  'cb11f632-b964-4477-85d4-4ebe50427a80': 'Ice Cream event itself',
#  '98fc25f9-398c-487c-b5d0-48f447457273': 'Banh Mi evidence include',
#  '943f3146-327e-4d1b-95f2-e52b5f452026': 'Taco plant loss',
#  '90772a83-50ed-4b71-9a4f-36180533af3d': 'Hot Dog for laugh',
#  '7c01bfee-f131-4a08-812b-453ac919576c': 'Pasta total call',
#  '7d64f013-0fca-481d-8161-06e9ec4f4081': 'Banh Mi situation across',
#  '7a074826-1412-4479-8f09-0d3e14271101': 'Rice pattern serious',
#  '5a89a2ff-e83a-4f94-900a-e2e6342fa3b2': 'Takoyaki across memory',
#  '59890039-912c-4fc8-8e24-8829210717d0': 'Rice example draw',
#  '4f253910-749f-4327-82b0-176d9625609e': 'Takoyaki audience scientist',
#  '452478b1-a1c3-4c6e-9a7d-50ec7fb0f7dd': 'Taco economic cut',
#  '31cd7bd1-a1af-4130-8ab3-b33f3d6af132': 'Goi Cuon civil her',
#  '2b9068fd-2ebd-4c77-998c-a4b06e5e2524': 'Burrito mouth everyone',
#  '1960d82b-a2ee-4bd0-b814-d387af738470': 'Pudding including data',
#  'fe5e8412-2ce8-4d92-b3bf-329b53b92567': 'Burrito country instead',
#  'f21a3d8d-0ab2-421d-8359-635e43bf8f05': 'Rice democratic career',
#  'f1f05565-f01a-405d-82cf-8c456d821e7f': 'Pasta agreement word',
#  '9ec1e22b-083c-47e8-a4ce-67fd5f3ac0a9': 'Ice Cream glass business',
#  '92a1e8f0-5bc7-4cb7-a01f-cd31853a4be2': 'Dumpling each common',
#  '85345545-818e-41c7-9bc4-0f70e53acc01': 'Ice Cream opportunity knowledge',
#  '6367181e-7e55-4dbe-b446-0eebb291e954': 'Pudding unit effect',
#  '24f71752-4fb4-47c7-afbf-acb0f782e8ae': 'Ice Cream cost morning',
#  '229d62b9-e622-4c4a-b4e6-aca52d07be21': 'Banh Mi three able',
#  '19791580-2610-48d7-84a4-a46c8973e367': 'Sandwich page film',
#  '01e47ab7-1a7f-4e4c-9cd8-afec82ddf422': 'Goi Cuon color model',
#  'a0854e48-7d46-4c4c-9fe3-fe5e81716b6f': 'Hot Dog build owner',
#  '5f2ea03e-fe56-4f9e-82f8-a2c3b9e188ac': 'Banh Mi late great',
#  '944b80e8-3e61-46d7-a0e4-fdd89c4dbc42': 'Pudding finally tax',
#  '2e3139c5-c3d5-42bb-8b17-b8f0bdfcb79b': 'Hot Dog mean friend',
#  '0982182c-8566-4acc-ad39-0f83f60da8c4': 'Pho human movie',
#  '38986c54-b4ee-49d1-acd5-61c6a4bf27f5': 'Salad wear get',
#  'eb3542e2-62bd-4535-85b2-b47b05bbffa8': 'Burrito imagine door',
#  '863f93ac-2b7d-47e8-8815-55e2755ca9f7': 'Pasta leg account',
#  '26d18661-6ae3-48f0-b437-b4b8ff7bdb65': 'Pizza guy method',
#  '2045b73b-bd74-4448-9768-273df608da28': 'Banh Mi skin life',
#  'd8d9b603-4af0-4c86-8e55-767e50c9588b': 'Pasta skill reality',
#  '3bd61d1a-7e8c-4073-a97d-e597bf5fc056': 'Pudding son keep',
#  'f99af79f-7ea2-44bc-b7d6-7e5d36324372': 'Sandwich child rich',
#  'cb014d52-a0fb-4426-a3c2-2be691b63227': 'Burger left try',
#  'a31450b8-9693-4be9-8000-855098f4c7d5': 'Cookie pass better',
#  '904c5634-1eaa-4599-9747-f559367d9c11': 'Salad house really',
#  'ee787d3f-b040-412f-ae4e-4982852a4fa2': 'Takoyaki occur level',
#  'ded52b12-c2db-4d64-a195-8b6561365ad4': 'Taco still house',
#  'd1d93c49-a389-49c3-8e36-30548cbb3f2c': 'Burrito eat over',
#  'd0eb7bf8-3181-4573-a501-51f9759164e2': 'Hot Dog sign into',
#  'cfef40e1-28ac-4755-ab53-92f18bb28f33': 'Sandwich fact project',
#  'b4e461b1-f74d-4de3-9386-6bd7a0883cc7': 'Donut democratic idea',
#  '9d28c042-e7ff-4b16-b4bc-999fd14b8f33': 'Goi Cuon war save',
#  '9b28b482-71fc-4920-8efb-28000f21fd95': 'Donut company camera',
#  '84788ca2-ec09-4e15-8bba-7e98ba86d12c': 'Burrito while though',
#  '7de8ea55-a374-4e66-a033-a54d0431cb4b': 'Pizza chair employee',
#  '6c35d23f-31e3-416e-bd2e-b1d56deecac0': 'Hot Dog control notice',
#  '413e9e60-623d-42c2-8c96-6dc9711ba3db': 'Pizza indicate practice',
#  '306c9168-91d6-496f-bfbb-8d6fd1f11789': 'Salad source possible',
#  '2c4a6835-5387-4063-a942-8f76a83a9435': 'Pho despite part',
#  '260b6349-fb1b-4d64-aa7e-0e41f3efa686': 'Taco thank anyone',
#  '225eff89-62c0-463c-9143-764c47ac6ff6': 'Takoyaki it billion',
#  '1ad3ff88-5e3e-4b04-9542-fd4df01e0e2b': 'Donut daughter south',
#  '0171b354-75c6-4603-b25c-6de8afd5e6fc': 'Banh Mi involve success',
#  'af7b02bc-f6ff-4376-bd25-29b589246fe7': 'Dumpling question itself',
#  'ad7a0d73-dc0f-4151-b9ed-08e050ccdf84': 'Burger produce economic',
#  'a430193d-8ee1-4d39-923b-e8765c287577': 'Rice bar century',
#  '90fdbacf-39ea-48d1-98a6-69f6d6ffea23': 'Salad win campaign',
#  '9796aa84-a4c0-4b17-9475-40d0b49fc9c7': 'Pizza performance look',
#  '83c4d108-b0c8-403e-8bca-1c11a61d0d2c': 'Cookie control our',
#  '7a4cda2b-f540-4a16-baa2-892710545281': 'Donut stock run',
#  '6c4be15f-ae11-49c2-a9ae-8a37cd5a8d27': 'Pho usually deep',
#  '592e8399-41a1-4d54-bf88-e9f53c885a32': 'Dumpling professional interest',
#  '587bc5aa-e54a-47fe-85f9-81c508c9ba86': 'Hot Dog white tell',
#  '495d74a7-ae63-4449-afeb-ef9ed9295f2a': 'Donut military board',
#  '4370a740-35b9-467f-b5f1-11d18d7f87cd': 'Pudding next down',
#  '38e88f4d-9bc8-4653-94f5-d510ddd372ff': 'Burger discuss reality',
#  '351616f3-9b5b-4b02-a953-6a26ac905e9f': 'Donut kid end',
#  '2ba850d1-1e15-4c19-b3b1-ae656c8641f8': 'Burrito happy age',
#  '1a3d1690-d00d-4914-b8ad-75bdbd38141e': 'Hot Dog maintain peace',
#  '19b8a652-22ae-4df2-958f-6605a82e5c70': 'Takoyaki claim wife',
#  '0f8d50e9-cdc6-4978-8fcb-810ecfd55085': 'Ice Cream pressure dinner',
#  '0ace37c5-ef69-4874-b6ae-856b4343ff87': 'Banh Mi thus start',
#  '8259c6aa-cf2b-4309-9ae6-96a98e88c65d': 'Salad action benefit',
#  '4d545d57-07bd-4616-b578-304ed9f46fcb': 'Ice Cream food important',
#  '1de70537-6ada-4e26-92a8-ebbb19e28726': 'Pasta near measure',
#  '3a99fb3c-723f-4825-8aff-b7e9fe94a7f1': 'Burrito effort job',
#  '221bcaff-0379-4920-9d1a-6b50a56658bc': 'Salad play special',
#  'ee2f96f9-d0b2-483b-9a60-0b5762dc8b93': 'Goi Cuon to grow',
#  '5ef41685-884e-4bc7-8587-97cd231c54f2': 'Donut admit attack',
#  '72e2716d-0f04-4c04-accf-06e0d2e68ebb': 'Banh Mi consumer cost',
#  '3b28c2dd-d957-4e2d-b340-9ce781d28b08': 'Salad later wonder',
#  '2b337df7-367a-4db7-bcb9-3a28a9bf37a2': 'Cookie than bill',
#  'f7df1222-8ed3-4385-bec4-aed8da3a4c10': 'Donut health put',
#  'd593ada3-f3ae-473b-ba92-959cee4a1842': 'Goi Cuon involve receive',
#  'd1e93397-7a4d-4e48-ad37-20bffd9fef61': 'Dumpling anyone unit',
#  'c56c4c23-8b15-47ac-853f-77ac82603771': 'Rice manager reality',
#  'c2c0df37-46f6-4bf5-a7ac-8a5875d460f2': 'Dumpling garden window',
#  'b8eef79d-6fd0-4eab-a672-c89d952f226a': 'Cookie at particular',
#  '96af2a89-44d0-4b0a-874f-41e84313e5fd': 'Donut condition skill',
#  '6f54bb9e-016d-45e5-a461-8734f92476b7': 'Pizza usually serve',
#  '209ba25b-677f-4fb0-8b55-3e67e3294555': 'Salad pattern still',
#  '0a85d0ca-7dc9-4445-a69e-ed2495d768ac': 'Burrito wish move',
#  'f9de3430-41b9-4db2-84af-2f5b7ea574f7': 'Dumpling baby relate',
#  'be832417-9902-44f4-b21e-2beea3b0fa58': 'Goi Cuon together rule',
#  '915b3561-4743-4943-b76b-d24c500f0048': 'Sandwich impact occur',
#  '5e938891-4301-439f-ab7d-6d1fb9a7a67d': 'Pho return entire',
#  '8f83aafb-c10f-4967-a3d1-0088227884c3': 'Dumpling parent miss',
#  '39130f48-bead-4c1d-b24b-cab7b140c8e4': 'Banh Mi international author',
#  '2f2fa379-8027-4020-bf54-be5eb0dbf1dc': 'Burger color study',
#  '067fe725-cb81-434d-b8de-a161d4798b93': 'Sandwich off head',
#  'f74f2753-8d8d-45df-90fb-cd4effc5c746': 'Pho image middle',
#  'dbf7ed6c-cd7e-4584-8b9e-cb1e83a6b002': 'Rice people dark',
#  'd022d1b5-1895-4860-a21d-8f8ea1bf96b6': 'Donut director tree',
#  'bf61650c-6f56-447d-9e80-e0b608bb637f': 'Rice leg movement',
#  'ad8b64e9-47fd-44a4-b65d-a5e12b650d12': 'Pizza anyone education',
#  'a5ec17e2-e14b-450f-8ad9-0e03eeab7027': 'Pizza score make',
#  '9b40d7bf-890f-4d07-b725-167292018b13': 'Banh Mi deal worker',
#  '5741f954-ceb1-402e-94cc-f1ec973627c5': 'Burger maybe goal',
#  '55501ef6-7764-4450-b26a-9f8b37e7033d': 'Taco word forget',
#  '48f12363-8e59-4126-ab72-faffdf156ee3': 'Banh Mi hospital she',
#  '4769a5f2-8335-4167-90c3-5f896c000d62': 'Goi Cuon address their',
#  '402cd60b-f5c3-42c8-9497-ece5f42cfce2': 'Burger back state',
#  '3b48591d-bb14-49e8-957e-671b8b1c32da': 'Banh Mi able off',
#  '2acb1fc2-4089-44c7-aa44-84bf5d244dfe': 'Dumpling so new',
#  '2024a662-2dbd-43e2-a447-136f6689ee9b': 'Hot Dog myself bill',
#  '0c3d3632-4ae5-431c-a13a-d120032dc7e1': 'Hot Dog fast less',
#  '02f20ec7-e1a7-4f26-86ff-7a67f7d375e2': 'Pho any building',
#  'e96d3665-9cb3-4ecd-89ab-dd689cbd7741': 'Pizza career blood',
#  'ddfa4808-4ae9-49e5-b8b9-5cf954af7adf': 'Hot Dog smile from',
#  'daa55b1e-0eb5-4098-9cc6-5e8512b2890d': 'Salad attention else',
#  'd4dc7c32-f07b-4d75-b8b2-a4e30e9de900': 'Pizza reveal establish',
#  'ad6febf8-eb1a-427c-9297-8b8c6eb68fda': 'Takoyaki purpose quality',
#  '9e9f4ca6-43ce-4c4a-b7e0-8dae291a66cd': 'Burger relate population',
#  '9e883807-64ee-434f-9b35-7f183e8bb166': 'Pho former democratic',
#  '82c569ba-2caa-41f3-a2ca-a65799a8972b': 'Burrito chance yourself',
#  '5d244a03-7f7e-41e7-9e3a-9dabf76abde0': 'Dumpling high win',
#  '5f0e8730-b977-4c13-aef1-0723bdadf27a': 'Goi Cuon suffer four',
#  '5332c83d-f819-40a5-a286-9b56ae25e731': 'Goi Cuon test forget',
#  '5b5e795c-e7cb-474b-8b34-84aa259e22f5': 'Dumpling ahead trade',
#  '38cf7183-a7ce-4890-99f1-a63caacbb5d3': 'Dumpling study full',
#  '3f2f08b2-22c4-451a-af4f-7930f23c53bc': 'Donut sister tax',
#  '323576f9-d83e-4f67-aec9-040a4c99c908': 'Pasta continue because',
#  '1a4b3871-c73b-4ed9-a918-24b9edab36e1': 'Dumpling long decide',
#  '0c83ec3e-7a5f-4b41-b9be-7fad20ccbb37': 'Ice Cream ahead become',
#  'f32a67b0-8595-403a-9e80-e20c3bf8b108': 'Sandwich agree detail',
#  'cb3d3c00-dd3a-4357-b834-8ada96f0b730': 'Ice Cream culture green',
#  'aef8290a-0120-4d57-adbd-4762354981c3': 'Pho world question',
#  'a8ad464b-3921-4542-8441-2629ace476ae': 'Pasta trial form',
#  '23914a35-bc7b-4210-b1df-42d882b642f9': 'Donut data president',
#  'e974c99e-91c0-4cf1-b4ee-716eed1ac969': 'Pasta if drop',
#  'ffd8ff28-90ca-4cf1-b3e5-7611ebc2f502': 'Ice Cream stock be',
#  'e28fd0b5-55bb-4755-979c-2ef2786d5397': 'Pasta choose safe',
#  'd489627e-1d79-48b4-aaaa-5e13e6da8979': 'Rice three pay',
#  'b1cc58f1-f666-4c71-9b63-5cb113538f12': 'Dumpling government since',
#  'a80b3fb5-abc8-4f3e-896a-536a05a757b2': 'Taco network here',
#  '9d4bbebf-d2d7-400c-b1c8-4361a47efb84': 'Ice Cream her couple',
#  '8486887b-52c9-4601-b697-6140523a7ea9': 'Sandwich girl color',
#  '80c75cc9-6c3b-49ef-a864-0b0a0980e39f': 'Banh Mi bank including',
#  '70fd88f7-173d-4c43-a35b-967224d0ed12': 'Taco knowledge since',
#  '6dcd2a8b-c9fb-4a92-91ec-f47b7ed67214': 'Rice physical like',
#  '673a280b-c5b1-43d3-b5b1-2e7c14e240cc': 'Donut against current',
#  '65b920dd-245d-43e8-b1e2-42c1943623e2': 'Goi Cuon easy red',
#  '3715206d-c383-4fa1-aea3-033532c9f434': 'Pudding property before',
#  '1ef727ba-942c-40ca-8a5a-a48c77ae9dc8': 'Burrito director data',
#  'fe0c3fc9-b865-47c8-9163-74119cb8d1a0': 'Rice street long',
#  'dc7ac3e7-8692-4b6d-bf10-de95eff85766': 'Burrito blue arrive',
#  'da5fda81-c126-4d29-ba80-538bf8af314c': 'Rice with fast',
#  'c894f0e6-7a25-41b9-bfff-6bb2bf0dded6': 'Ice Cream although score',
#  'b6deb2cd-90f9-438e-8e92-167bb8069a6c': 'Taco along test',
#  '6ae233a6-8895-477e-b05b-af0871f653ed': 'Pizza ground film',
#  '1f32acc2-9c06-48fa-8b8a-d9e23f45614b': 'Sandwich system like',
#  '1aa20fd3-35b8-49db-9113-1715fd0b4e76': 'Burrito so point',
#  '0db2fa56-d33c-4f09-bfb6-4c26001f0729': 'Pho me career',
#  '0d468f04-0b87-47e9-8e8d-334a162ca4c5': 'Goi Cuon guess picture',
#  '007cd656-a676-4428-aa6b-9eff964a16c3': 'Goi Cuon apply wear',
#  'fde88927-ee90-46b3-9e93-b26d78d682b7': 'Pizza become spend',
#  'f833974e-7e19-46e1-8d89-2b449ebd7d1b': 'Sandwich pull bank',
#  'ee5029bf-8245-4193-8bfd-afe8a29b5a68': 'Pizza agreement north',
#  '977139c1-1564-43a1-8c2c-4f69548e31a4': 'Pasta truth both',
#  '78117943-72ed-4c67-a0c6-e23ee9e82a2c': 'Pizza magazine generation',
#  '26bf3ea3-0047-47a4-8bd9-0ae078653dc0': 'Ice Cream exist explain',
#  '24533163-4ce9-4b45-8ec9-4902cc421db7': 'Dumpling buy small',
#  '4d8b4781-90e9-430c-b10c-9ea398d77dd1': 'Burrito high begin',
#  'af22e052-d772-4fe8-9058-7eadb30b79a9': 'Pudding right three',
#  '509ec9e7-bf79-45db-99c6-43602a48acbf': 'Donut during almost',
#  '2f900a55-8a6a-4ddd-af99-3280c778e3c3': 'Rice his leave',
#  'f9a0b3fb-391d-4d16-ab6b-fb8fdf501606': 'Burrito probably across',
#  'f37c90de-9e28-4e0c-87d1-e707311ab885': 'Pudding design interesting',
#  'e9855b1e-209a-4f95-bec0-7038f2990ed6': 'Hot Dog less board',
#  'd3abb581-5b9d-419c-bdad-3f4b42c66e32': 'Banh Mi region stop',
#  'cebb43d4-6fec-42fd-ac7f-c01b3e158613': 'Burrito senior money',
#  '979e9b9b-1d7f-462a-ab6c-8b9d1d7cf96e': 'Pudding seem improve',
#  'b132736a-f7aa-4f1d-876c-565149b1e0d0': 'Burger receive pick',
#  '855d4578-3656-4255-8d28-fb4b84525342': 'Burrito second responsibility',
#  '869fdf00-c0dc-4c5a-b7f7-f471079af282': 'Salad growth result',
#  '665d7713-2506-440c-bfc7-48477ddcf47e': 'Goi Cuon in her',
#  '5dd1f1ae-92be-42cf-9d5e-7af378dd4394': 'Burger remember else',
#  '4a7fb718-fd1f-4934-9e7c-2ceb468c7cc0': 'Donut office chair',
#  '3755e2ec-e954-4925-9489-6f430378bab8': 'Pizza capital score',
#  'fb83cdac-826f-4854-9488-33f2158b6f7b': 'Dumpling could try',
#  '59a58b03-c7b0-4e4e-8fcd-290154615c54': 'Dumpling responsibility consider',
#  'de1d5a63-06eb-4eac-8c2a-ddd4452875b9': 'Burrito item race',
#  'd33df8f7-47c9-4e48-9831-bc27155495a4': 'Burrito tree science',
#  'c9626fe5-0732-4060-9b4c-f42baca16973': 'Donut fight front',
#  'c76b9ad1-ab30-45c9-9014-91e6e8c8d02e': 'Pudding would and',
#  'a057cb34-d1b1-47e7-82d1-c918a0fa8286': 'Taco present future',
#  '905474d1-a6fd-44bd-bcbb-5fdd86d2d100': 'Sandwich near exist',
#  '8164719d-4bd6-44ba-a7ca-0d729916eff9': 'Banh Mi page manager',
#  '8138ac46-ce25-4012-be3d-9963fdfb1c4e': 'Ice Cream seek story',
#  '80eca178-c462-439e-9beb-ab9c37a7f938': 'Pasta surface forward',
#  '80c25c4f-a633-4076-acea-956c742fe4bb': 'Pasta almost fact',
#  '5818350b-211f-4f43-bd2c-8c5cae29868f': 'Ice Cream billion resource',
#  '55a72bf3-f479-4beb-90f2-0a45b365da2e': 'Banh Mi until night',
#  '4a8691e9-da3d-49d7-bd95-4da34ffc461a': 'Takoyaki poor exactly',
#  '383006f5-d5bd-4cc6-a49e-62f824527fe1': 'Dumpling notice perhaps',
#  'fd763280-a5a0-4c1c-8e2f-8c3892ef86c0': 'Takoyaki next toward',
#  'e8e96065-a01a-412f-8f79-8cd90b361a75': 'Salad finally impact',
#  'dc010b62-7686-49c2-9a69-bac655a46806': 'Pizza data the',
#  'ce5bf42b-91dd-4c1b-b861-3fe1d2334556': 'Burrito network present',
#  '9f83a602-b354-4a00-a4ff-2a690e3e0f5d': 'Burger that people',
#  '53f0167b-5537-41bf-a5a7-bb4fcc8244cf': 'Sandwich Mr explain',
#  '4ca8ae3f-7eca-4d9d-87f2-2bbf3cae1fd8': 'Pasta open body',
#  '32007e43-9cc2-49a2-a7e7-1d3f09526c63': 'Pizza practice politics',
#  '03ba72f3-f529-4c53-a850-6af5e9f31a35': 'Burger nearly back',
#  'f4a197e9-eb8b-4916-94c6-1ffff60107e7': 'Taco else spring',
#  'e255c404-6123-4809-aa23-f82606e31bda': 'Pho exist little',
#  'e21422b3-8494-4737-a4d3-ceae27be9a39': 'Cookie security poor',
#  'd6a75b1d-ba8a-44f9-8eb9-0cbcce359fe2': 'Banh Mi find claim',
#  'aa6acfb1-af60-458b-9a40-486e1c808a9c': 'Goi Cuon network pull',
#  '9a06d319-6c82-4389-b8d9-771ae313284e': 'Pudding deal operation',
#  '9053abe4-1fc3-44a3-b645-e83ea178f15c': 'Ice Cream as option',
#  '8c7324d9-a57c-4294-88b9-68a877a7ccbb': 'Rice impact figure',
#  '8c294a62-12fa-478b-bcb4-0d39729a1684': 'Taco study able',
#  '83eaf27d-3fd7-437d-8439-e5c601e4891a': 'Banh Mi yet young',
#  '73ddf950-ef29-47dd-b32f-1e35c372f30a': 'Cookie start best',
#  '4bc940b6-4722-49df-904a-839162c631de': 'Rice pressure there',
#  '02b25950-4537-4fa4-954e-f22b61dd97dc': 'Hot Dog spend despite',
#  'ea9af709-3912-44e5-a972-4dd0f4a27b8d': 'Goi Cuon result property',
#  'e8f235ea-bf15-4181-bcfd-e57587481afa': 'Burrito dog chance',
#  'b4c1df78-0880-49b4-bcc9-f46232d66218': 'Hot Dog hear quickly',
#  '9ad0babc-87a6-4a0f-b1ae-3d074cf6b2e5': 'Takoyaki very bit',
#  '7c258c5f-498f-4ad8-9301-fb1988a087dd': 'Pudding often way',
#  '4f8d258d-a58b-440d-9b49-5948da0f6eb4': 'Dumpling use career',
#  '3289f2cd-be22-49ed-aa0a-ac83aca51534': 'Burger institution husband',
#  '2f0588fa-3265-408f-9733-57a7062c02c1': 'Pasta note participant',
#  '1d0df2f0-54df-4644-be48-2cf580b977c7': 'Pasta truth describe',
#  '176140c2-3736-4ddc-a722-fdb1bddb8b5b': 'Pasta imagine develop',
#  '155b6f46-267c-4131-afbd-56fe2404f90c': 'Hot Dog power hospital',
#  '0d7deca5-cfb3-4bb2-b655-250dce8086b3': 'Takoyaki explain hold',
#  'd3250de0-b20a-4e63-aee1-2290360ae2f3': 'Salad north foot',
#  'b46522d2-305c-44aa-81d5-52123eaf5e5f': 'Rice professor meet',
#  'aa24a60f-eb01-4821-84c2-73ab378fdf55': 'Rice worker keep',
#  '99d7c0b0-c205-4878-a63e-36e8fc5fe600': 'Cookie level eight',
#  '6515fc5d-fcf1-471d-af24-236bb13285f4': 'Banh Mi TV yard',
#  '2b43a79a-779e-40e1-9166-726e76db3bcf': 'Hot Dog report realize',
#  '09575682-0352-44b5-a1ff-529d48c4206e': 'Taco hundred coach',
#  '08f6d1b1-5c97-4f40-ab8a-e05ee3c33af7': 'Goi Cuon eight tell',
#  'f17511f8-d5da-4fae-9106-ae3e69478ad4': 'Pho require night',
#  'fcfcc78d-2109-4eaa-941f-955c128c863b': 'Cookie court situation',
#  'e5932d12-4994-4cd4-ab9f-b6baef9d971d': 'Ice Cream know along',
#  'd9f564fa-6bff-4caf-968c-fcc2f6807b9d': 'Taco media key',
#  'd884ae10-ec7e-4cd9-bd35-5d61a6da1cc7': 'Ice Cream whether address',
#  'd7492c0d-f5c4-44f2-bdbc-d897812e1383': 'Rice ten live',
#  'd7c508b6-ed35-4904-a091-7fb7b1e0f9db': 'Hot Dog write leg',
#  'c13734ac-0c55-4ab3-8aac-69d02654981b': 'Dumpling determine wife',
#  '6c884f6a-24c8-41c5-be6a-2b4b1d63d9c3': 'Salad second thank',
#  '6b40414f-9387-4344-811d-92e37b312fc2': 'Rice chance fly',
#  '23728cf1-4a70-42fd-b790-4e1099a0b85c': 'Hot Dog head difference',
#  'e19d955c-4341-4da7-ba4b-596514e00fd7': 'Pudding federal event',
#  'b6ae7ac7-aad5-44ee-9c5c-d5fe42cf42fd': 'Banh Mi school action',
#  '55ebd75b-1389-4890-b50c-ef4ed37271a6': 'Burger for almost',
#  '3fca9e1c-90ef-4469-8bd1-872fdef6a015': 'Taco eye open',
#  '35fe346f-7c29-4e89-b6f6-db56d86eff52': 'Donut oil history',
#  'ca40120b-f94b-4ee9-8748-e06cd88163f4': 'Burger meeting available',
#  'a6d999a5-833e-4f99-a532-75562312f6a4': 'Burrito seek central',
#  '9e09783a-eb24-4e91-9fad-464f0b183095': 'Pasta brother away',
#  '858adb08-bc60-4f2e-91ba-39c1c8465b92': 'Hot Dog talk nor',
#  '74cd44c0-85e3-4a62-8028-bd7f253feb75': 'Dumpling ever buy',
#  '45cfbc7d-d857-4bd6-80e0-58052ab1c2db': 'Ice Cream responsibility despite',
#  '43004576-3abf-44d1-8272-b865965175d5': 'Pasta resource you',
#  '301793c3-b5b2-40ca-a825-e44b8334e616': 'Sandwich economic family',
#  '266939b8-7f9f-4039-864a-b357d4ed2e04': 'Burger language could',
#  '1e6b46cf-711b-4219-916d-f0c686ac2661': 'Rice itself happen',
#  'ef8a9100-2fd8-4e17-b837-f9a5c989bf34': 'Cookie cultural create',
#  'e470f665-1768-41b7-af10-597576d52a67': 'Rice more information',
#  'dd450204-700b-4e87-a046-ca9e5ac4b61b': 'Dumpling site free',
#  'd3e414e8-8056-4e66-8ac3-9d2568792b8d': 'Takoyaki century any',
#  'b437e74a-b077-4af4-9a85-0413b3d8d75a': 'Sandwich third result',
#  'a9382ae6-f1e7-46dc-9e33-7180733b9a0b': 'Hot Dog human staff',
#  '8c541dcb-53b3-4e8a-aca5-95b845b63993': 'Goi Cuon suffer certain',
#  '90d2bf9f-23b4-4991-bd8a-ba34fea2cb32': 'Pasta rule feel',
#  '7b1e06af-50ef-4a79-afdf-f6a80f55e38a': 'Sandwich positive edge',
#  '74e9915d-8ca8-45be-a3d9-1469cd9dcef8': 'Hot Dog after hit',
#  '5ec8a5c5-4e43-4bce-9357-65e4dfb7d6b5': 'Sandwich have my',
#  '3c44cdde-b23f-4ed0-9ba2-f2eed0c0598b': 'Pasta notice thousand',
#  '3852b510-480d-4b54-a52b-aafd6dd21711': 'Pasta table manage',
#  '23f7e1ab-c755-48dd-8c6c-03f8b7acfdb0': 'Burger adult movie',
#  '2022ecb8-7c90-4775-867f-6ac75bc1b8ad': 'Goi Cuon build add',
#  '86bdeb1f-9a38-45c2-8296-d47a6e6707fc': 'Goi Cuon discussion design',
#  '747fcd53-7b81-46bb-8f8d-e5932e2dae5a': 'Cookie room religious',
#  '6d2cf87f-ac82-4933-8ce7-c97ba2f988b4': 'Pho manager out',
#  '3bfa6409-01b5-49e2-9af6-24c4d9832c55': 'Banh Mi cover gas',
#  '28e1d89d-3aaa-4e8b-bcd5-f6d35c3b1118': 'Burger bring maintain',
#  '21d0e3fd-2999-4161-9a3e-8c22bb7db755': 'Goi Cuon citizen task',
#  '04c42a59-f04b-4029-9c5f-3be394b4cc39': 'Cookie administration plan',
#  'fbc57c5c-0cd2-48e2-bc2e-c983d2554700': 'Pho seek major',
#  'f1039d88-9c0a-4534-bebb-9c0f17084fae': 'Donut rise line',
#  'aacca512-db94-48ae-b478-ad413f436662': 'Salad with kind',
#  'd01a3334-cc7c-425a-99ee-6b250ceac53e': 'Pizza yet range',
#  'a1cd133e-0bb7-4145-b2b4-8e85394fa67d': 'Donut Republican role',
#  '9b72f2c0-12be-4e15-9a46-8dc94e857d41': 'Taco any fast',
#  '8a698646-43cb-4756-9466-2f31095f5cf5': 'Banh Mi another identify',
#  '54bf600f-218d-47bb-aac0-c6677e9b9b76': 'Rice until drop',
#  '53146257-c442-44a1-a658-874bdb710681': 'Pudding line sign',
#  '4f268dda-ad3c-44dd-a429-a04ca229d47e': 'Goi Cuon summer use',
#  '46d64f42-dd3d-4a78-9cff-68322190f924': 'Cookie imagine center',
#  '0d4d4ed1-ec24-4191-a0c3-007c0dbed5f6': 'Donut recently story',
#  '034a54f2-dde9-47eb-96c5-e7165d061a44': 'Burrito low participant',
#  'fd3fd4e4-372b-4d35-bcea-c2731f1b226b': 'Sandwich fund resource',
#  '700ad0ed-bbac-4860-a06e-654062bb3289': 'Salad on you',
#  'e2dbbd69-d295-4ed7-869b-2afcbcef4621': 'Dumpling instead no',
#  'd43019fb-4bf4-4c8f-bd4f-91aa47621bf5': 'Donut professional question',
#  'd34e1e55-25dc-40c4-93db-e61d009334a9': 'Sandwich least happen',
#  'd022fb9f-ec1b-465d-b838-a5e49208b6d8': 'Goi Cuon size focus',
#  'cb577ea5-7286-40a4-bb2a-fe56b827287b': 'Hot Dog because sing',
#  'c45e4653-69b5-46ad-9e67-b70a1bc80dca': 'Burrito fill yard',
#  'b2f70ced-4c58-431d-bbae-95985e1fed82': 'Salad current manage',
#  'aaf17ca8-8bb7-4794-82cb-4e9bea61856c': 'Dumpling collection event',
#  '7f13d19a-5653-46f9-8336-618c99af59ae': 'Takoyaki really good',
#  '4db97352-f632-4f95-9ad3-9802c704c3ba': 'Goi Cuon open charge',
#  '1530f6a0-d10b-4140-b07a-f575e1bd5703': 'Pasta them best',
#  '8a9d5fd3-061c-4286-b1ad-407c8ee47b73': 'Salad easy born',
#  '1f211178-9537-4565-93db-a2d903673fed': 'Ice Cream piece her',
#  '09e47c81-01ca-473f-a7ba-7df637dc25cf': 'Rice training community',
#  'e9ec80d9-105f-4fe6-8361-73a384a6dc40': 'Donut charge section',
#  'de43ca04-889a-47e7-827e-d58d1bf2a2d1': 'Goi Cuon note activity',
#  'da913fd7-62d2-45ea-b4eb-153340a839b7': 'Takoyaki into sister',
#  'c7c5787e-0adc-40a1-825e-75dfbc5ca2a7': 'Salad middle theory',
#  '88bf121e-2e31-4ecf-884b-d5af46477a82': 'Cookie win lot',
#  '5df369f5-73fb-45dc-a619-84fbaa95366b': 'Burrito age commercial',
#  '633fb552-9fc9-42a4-8fcd-3f5bc1f4f58e': 'Hot Dog it show',
#  '1b410512-7552-445d-9857-45fa9cb2302a': 'Donut wall local',
#  '10f84de3-f505-4937-9098-ed06457e09c4': 'Rice continue camera',
#  'fb89a44e-18ed-46bc-98b2-073eff49ba9e': 'Salad whose compare',
#  'ed0ec367-8623-4621-9555-ab4f936b61c4': 'Donut police prove',
#  'c8bf90f3-2b90-449f-be1c-4d7bdfa8fb63': 'Sandwich conference forward',
#  'c30daa3a-926f-4921-ba80-ec69f71a2407': 'Burger course avoid',
#  'a14fd83d-28e1-4746-a206-24d36b06c841': 'Burger anything large',
#  '7892027c-6569-408b-9aef-f7895d02ec9e': 'Cookie decide go',
#  '71a80f91-e0f9-4891-b279-35972cb52c1e': 'Ice Cream event and',
#  '6efe51b3-46d0-43d0-baca-ffef189a43c0': 'Taco night important',
#  '5bfd3cce-2be9-4397-b4f8-0715f3557ba8': 'Goi Cuon history occur',
#  '53b9cf0b-cb78-4072-b83e-784d3673e320': 'Hot Dog do alone',
#  '46185339-9d65-4098-b82d-6091dd9f615c': 'Burrito success current',
#  '2d3def02-77b4-4eb3-868e-758d56de18f2': 'Hot Dog enough certainly',
#  '2ce7084e-348c-4737-abf0-a350c967f903': 'Pho popular someone',
#  '208753f0-1b82-43fc-920f-2b69a041b2b9': 'Cookie in bag',
#  '1d7798a4-1dbe-4fbf-98a5-083ee4258d2e': 'Banh Mi far sister',
#  '0f871b07-47f0-4329-b3bb-45ff007e939e': 'Dumpling alone world',
#  '0d190504-f50d-4ebf-a376-a634bad6c55e': 'Pasta production rest',
#  '0b39c237-2eea-4238-8cb9-44c9a1cb9b68': 'Banh Mi any field',
#  'cd56ee2a-6a24-4455-a653-2372f070bf62': 'Taco once game',
#  'b032f7be-ac54-4061-9880-576d1dd584c7': 'Banh Mi next onto',
#  'a45ebb44-0ce5-4f61-b716-01ecd8c710fa': 'Cookie suffer feeling',
#  'a237caf6-e6e4-4775-b627-ce3e0bef8876': 'Salad tonight door',
#  '79f3d8ec-8d18-441e-ad83-b8b68d699004': 'Donut loss week',
#  '6ddab319-13c6-44a9-8326-64304bc32cfa': 'Ice Cream week finally',
#  '540db9a4-6b2e-4bc9-911c-02c16e70ca36': 'Cookie like while',
#  'f315980f-2a94-4af1-8a90-0d476dfa97d9': 'Hot Dog three structure',
#  'e6779dab-2147-4f08-9618-3ad01efbad02': 'Rice against short',
#  'ee04db84-5851-4526-87e8-d0f756e8c63a': 'Salad suggest beautiful',
#  'dff87c4c-e5f0-4fa5-8090-872df1846990': 'Pizza us measure',
#  'd1f3c40f-8220-4caa-a98f-0f885e79b8a3': 'Takoyaki firm agreement',
#  'c3b4b8b4-7c43-4dcd-ac78-263fef22ce08': 'Taco family yeah',
#  'c7223194-c2de-4db8-a07a-060f7e648b6d': 'Cookie operation rock',
#  'be865497-42fd-444d-9295-7af67143fead': 'Salad detail artist',
#  'a36360d6-5f91-4211-ae5e-81e340faa50c': 'Pho ten audience',
#  'ad4d20e8-3571-4f6d-bbb8-80696f603f50': 'Ice Cream term daughter',
#  '9f062ddf-b721-486b-9609-5448c9a766b3': 'Sandwich similar role',
#  '6d4b98cb-1d70-4708-b2ed-0b6f2b3a2927': 'Cookie save decade',
#  '7a6509b4-79c0-4b60-ab4b-d0274f33598d': 'Burger worry most',
#  '53455628-5d11-4115-9135-061325a402b1': 'Burrito action though',
#  '33207172-8bd1-4002-a708-cc3246f2c9ee': 'Pizza occur interesting',
#  '2863dcf0-5994-487a-b180-f9c8a1fbfca3': 'Goi Cuon design one',
#  '1b48eac9-513d-45ed-86ae-a36b74166408': 'Burrito hold particular',
#  '1a52eea1-4283-4c82-a31f-d25445e01de6': 'Salad area stage',
#  '0467ab56-f383-469e-b845-a8fa37c42d19': 'Taco add remember',
#  '00f1a2ba-5663-4382-b0ab-4ef7a4078d51': 'Burger mother skin',
#  'e0ea4a4d-ae9a-40ba-a589-ca1cf982925b': 'Banh Mi director place',
#  '4e49f4f9-442d-42da-a9ff-19e66e7868ac': 'Cookie defense under',
#  '45e9b14a-87ee-45d4-b269-6226acad0a3b': 'Banh Mi number sport',
#  'f0e96c3f-4acd-4f59-84a6-2cabdc99758b': 'Ice Cream remember number',
#  'f09bb72c-d32d-42b3-88e0-7ea2ebbab42f': 'Cookie paper word',
#  'a078eca4-4aa2-4a43-a575-ba6e6369709f': 'Salad three trip',
#  '70aca8bb-9fca-4f2f-914e-eab36a59c71b': 'Goi Cuon offer cause',
#  '60b3a09d-390a-4ab6-87e6-bab0606f9074': 'Burger score along',
#  'ffa96ee9-c88e-42a6-b06e-07b919067935': 'Pudding note player',
#  'ef351b23-7ec1-45ea-9a15-5fa1dd2540a7': 'Salad also pick',
#  'feefaf3b-c965-422f-bd31-6e4e9df808d8': 'Pho trouble who',
#  'ed112810-7908-4eca-9808-812af9de9833': 'Banh Mi wish situation',
#  'cea42000-9670-44e3-a2b6-b82894067e6a': 'Burrito clear institution',
#  'a0e5128a-5ba0-4350-be2b-0631e0901caa': 'Pudding indeed western',
#  '9e9a93f1-1c92-4d9b-9271-17c30d8e644f': 'Burrito attack fly',
#  '9dddd27f-15a7-412f-a6d0-1bfe6d11b4ca': 'Goi Cuon school bed',
#  '98ad3cad-8986-4342-84e5-adfbafde58a9': 'Takoyaki seat view',
#  '88174669-ef7d-420c-a492-457801499320': 'Takoyaki Republican would',
#  '31ee5a5b-72d2-44ca-8d7e-0646a53478c3': 'Rice room small',
#  '435ad44c-d531-4057-9636-fd0ec6c0835f': 'Banh Mi concern true',
#  '2b869141-657f-4b3e-9293-c525c24d9303': 'Sandwich real stand',
#  '2059d85a-b2af-4812-80a4-6f27670efdc8': 'Ice Cream suggest occur',
#  '16b40ee5-faba-4c20-9e14-eccc0bb03e50': 'Goi Cuon perform alone',
#  'f60bb919-10ec-42cd-b380-01b813da8505': 'Takoyaki good rock',
#  'aeabe286-1bd1-4ba5-b6de-856029b25d94': 'Burrito miss crime',
#  'a973127a-f7d6-491e-8f55-466655879fed': 'Pizza program much',
#  '852a7a24-7b02-48c7-a6f6-6ec171e2f769': 'Donut perhaps owner',
#  '5d9ce52c-9900-445f-a2ea-68af9de00bb2': 'Salad imagine until',
#  '5cdcc7d3-456f-4d09-9c15-7fabceccf817': 'Pho attorney choose',
#  '4e215aa9-72d0-4f0e-b128-a2486771b5d5': 'Taco magazine morning',
#  '2c3c4eaf-3769-45a4-8536-912fd2089c0a': 'Takoyaki other want',
#  '196e0973-004b-4b6e-a2f7-ca6240710570': 'Dumpling hour him',
#  '0e6d18f0-ae58-4ba7-9752-4a2db22996ff': 'Cookie consider technology',
#  '18709357-b3e0-42cd-a4c5-346851303a74': 'Sandwich fight health',
#  '0b350452-bd67-4d63-a615-b787bad807be': 'Goi Cuon thus offer',
#  '072abe4d-45f2-41ce-9df3-072db97a4a40': 'Burrito training describe',
#  'ce44201a-591a-4f3c-a2e9-241c67734ce7': 'Banh Mi statement research',
#  '9e60c1bb-043a-4d27-8229-38f5139aca9f': 'Dumpling wish final',
#  '91af968e-2cf0-4338-9755-6b9b2c2e36b5': 'Goi Cuon worry end',
#  '8ba6bc05-ecaf-4cda-a89a-75e338c130b1': 'Pudding simply take',
#  '7bcc78a7-d7e7-4508-af9d-8ab6f719b99a': 'Banh Mi child myself',
#  '6e93ccb8-b549-44ca-ade4-f8cdddbe58d4': 'Takoyaki fight collection',
#  '6552d167-5c97-47e5-8531-eb94fe0542b7': 'Pizza station business',
#  '572c28fd-8962-411a-aced-3ec55e7fbd12': 'Salad ago hair',
#  '4f72c27b-1fc2-4c27-9550-5e7a8ad24db7': 'Burrito rock new',
#  '4e0d90b4-4042-4319-b46b-ec40e4883228': 'Goi Cuon water too',
#  '458e4bf3-5632-4118-ac69-e8e4dfb0961b': 'Burrito court our',
#  '23eaea15-4084-4af2-9d84-525502d066d6': 'Pudding perhaps they',
#  '2f1e9b43-2418-457f-96e7-e77319012b05': 'Burrito include dark',
#  '1089ed1e-5b0a-4a94-b481-60c62e5fb3b0': 'Sandwich capital why',
#  '0f62e0df-1c3f-477f-8e24-6d5bffe83cfe': 'Pudding prepare candidate',
#  '0e1d5329-d7fd-4e15-b15d-6dad63f655dc': 'Pudding need something',
#  'fa5e9804-80dd-42d6-9537-7b0fbd1d11a0': 'Sandwich smile individual',
#  'c9f7ee79-cc65-429f-94a4-02228762c8ee': 'Taco time some',
#  'ab6bf0b4-ed91-401f-8c91-5d2143a9aa15': 'Takoyaki as we',
#  '15c4bdcf-0357-4d2f-b8b1-d3c43cd89d8b': 'Burrito himself miss',
#  '33371e8c-b8b4-452d-8749-4952f41e9c5b': 'Pudding project important',
#  '034274a0-5dd3-42b2-89e1-15fdc36f4645': 'Dumpling movement get',
#  'f2c03d5e-5417-4f74-a854-d413bf91297d': 'Banh Mi notice six',
#  'f29b5b22-1e8b-4196-afd8-a6acdc2237eb': 'Burrito section detail',
#  'e8472f00-e5e6-45f9-9388-28eeeea5d1ce': 'Goi Cuon property black',
#  'dffdf3ed-3a33-44bf-a85e-d1229fa9c8f0': 'Salad election same',
#  'bae03afb-41aa-40be-b550-bd257129e7a9': 'Pho whether far',
#  'b8ac22b5-56d5-4260-9a8e-427d3fdda613': 'Takoyaki such administration',
#  '9023cef7-0103-4cbf-a0c7-69cfd34b0efa': 'Dumpling choice issue',
#  '5cb2a22a-b43e-42a4-9246-e8bebfbddd7f': 'Donut financial rest',
#  '34b48474-7fd3-44fe-9e4e-34f7cc253014': 'Burrito look able',
#  '2eefdcbd-919c-41f6-b266-c5ec530418da': 'Pasta board brother',
#  '2ac70200-9ab0-4eb5-a365-040ee8cbf085': 'Taco generation edge',
#  '05d74e1b-5125-4cbd-ac64-90b0216967b4': 'Ice Cream increase idea',
#  'd62c2a7d-b2cc-4856-825d-a10dfaa73554': 'Ice Cream page technology',
#  '69178e08-ef81-4722-8518-c17be29e933e': 'Sandwich drop early',
#  '58c73d10-c910-4260-bb8f-935028b8699e': 'Salad war culture',
#  '4c31a5b8-e29f-468d-bbbb-024205eb8de0': 'Rice just building',
#  '43108c83-2d05-4b28-b42d-57f22f491032': 'Salad year wear',
#  '14ec09da-ad63-481b-a2b9-47ccaff6ad63': 'Takoyaki live purpose',
#  '03b5789e-23f4-48da-89f0-cf00ed04a71e': 'Takoyaki tell without',
#  'd8d57c3e-de29-4a5b-878e-194393ffcf06': 'Banh Mi arm experience',
#  'cf51d2e9-5c00-40d5-aac8-8b60b0d4d717': 'Goi Cuon structure relationship',
#  'c47d5abb-1a27-4a38-83e1-ab4e69229cf6': 'Donut treat practice',
#  'bff849d2-30bf-4577-bfea-5dd01dbf15fc': 'Banh Mi lay quite',
#  'b6c76c0c-4871-4c9b-9b22-b936105ef95b': 'Takoyaki record decide',
#  'a61b84ad-5f50-4066-a750-3f904db1b2ea': 'Pasta writer clearly',
#  '7ecb6aec-4419-4970-ac06-175e20635c08': 'Taco order yeah',
#  '5f4987de-88f3-44de-8262-3cb68931d0ae': 'Cookie none field',
#  '58dc3e48-015a-4578-b0ce-926ece0caa64': 'Salad future two',
#  '18d77450-9188-4604-9457-bebb3042b6c1': 'Donut enough officer',
#  '711c1d78-8cb1-4255-b914-6ef9b27d16b7': 'Donut real marriage',
#  '6f09937f-112b-4fa4-b3d9-ced052530c8b': 'Salad current do',
#  '426782a4-fd89-4ba8-a02f-f01d1f4117c0': 'Dumpling think authority',
#  '8da231e7-72b7-4f1c-a830-8f2316ee8282': 'Hot Dog list Democrat',
#  'c92a96a6-81ab-4442-8140-2c20f93d501b': 'Ice Cream fear recent',
#  '9447b791-95a3-4f23-b1f7-f9c028f3ee1b': 'Goi Cuon staff it',
#  '7cb2c709-de61-4b1d-931d-446834c7442f': 'Burrito plan party',
#  'f4ed324f-58bc-42ef-a7b5-815b323b6a6f': 'Goi Cuon positive everything',
#  'f84224b7-71f2-4491-9198-a63894bc8999': 'Burrito everybody second',
#  '9f011f8d-8bcf-47c3-8ab9-a78941d384b2': 'Burger suffer also',
#  'bd414ac0-13c0-49f6-951c-f10b32be54b2': 'Takoyaki nothing mind',
#  '9d9e3d79-bee2-4e1c-adb1-d98d40ecfaf2': 'Takoyaki make prepare',
#  '8dc3d2e2-8b35-46e5-a456-4c68d20d9866': 'Rice land lose',
#  '6b67d6ca-279e-4ad2-9aaa-0839170c1952': 'Salad police word',
#  '1ebc4679-baa9-457f-926c-30f97ebff176': 'Dumpling two build',
#  'fc9a9614-a531-4621-a1bf-2df961d59a72': 'Ice Cream more camera',
#  '96472e3e-0130-468b-a0cd-0be4a845e728': 'Goi Cuon able begin',
#  '84d168ec-aa15-4655-ae04-0c88ca688002': 'Burger pretty teach',
#  '68d43662-59d4-428c-b8bb-6230f02eb0a8': 'Pizza century may',
#  '3d613391-e9dc-4796-99b4-3d624d238700': 'Takoyaki task toward',
#  '32c7d8e9-ac40-44d5-b9ce-0cab256dbcb9': 'Goi Cuon less watch',
#  '260e6e8d-1729-407a-ac55-943ba231cc35': 'Takoyaki key market',
#  '226dd2a6-369a-40ca-a492-bd1be18f0ff2': 'Dumpling these side',
#  '1a02541e-9a3f-4673-97d0-02d935da54a9': 'Burger various if',
#  'ffdd0595-54bb-4790-8823-aa04569f5d16': 'Rice their spring',
#  'af1c1472-57da-4a54-b1af-d34107e3d88f': 'Pizza else determine',
#  '9b6739ab-9531-49aa-8054-835158eda14a': 'Dumpling sister where',
#  '955f469e-d773-4349-8368-618d7409c0c4': 'Burger art interesting',
#  '9a80a806-3afd-42bc-923e-0dc75e3db6fb': 'Pudding word school',
#  '798c2621-8c2b-493a-bb22-c430d4348cc9': 'Pho government artist',
#  '6b9f9da8-6f7f-43c3-a4fd-6305a6c448db': 'Pasta she easy',
#  '75a38c8c-bd02-48ee-b3cf-bdcb538919ab': 'Banh Mi under per',
#  '6aa1d86f-b42b-46ec-89ca-d1a5530bbbdc': 'Taco relationship cell',
#  '5f0c1796-84cd-4395-a028-2d2a3270a8e0': 'Hot Dog structure their',
#  '582e2863-f4cd-440f-9bc5-ded3bba84470': 'Dumpling develop about',
#  '54742141-604a-473b-a145-8ee358f41e0d': 'Ice Cream market man',
#  '4be57055-02e9-49ee-8b62-3a1f6db69b95': 'Burger each stock',
#  '427407e0-8337-4ea3-87dc-7bae87debfaf': 'Taco sport rather',
#  '2670f3f5-0021-4bbd-aef0-9659ce845102': 'Dumpling board boy',
#  '14d3271e-912d-42d0-b25e-be6bf1d70551': 'Burrito attention hot',
#  '119acad0-83c4-41f1-b254-1cc693b60e15': 'Pasta their attention',
#  '079331be-659d-40ee-ae39-6a38b2687df8': 'Rice study some',
#  'e3b51201-9b96-4cab-8e74-14bf50f90796': 'Pho government want',
#  'bc19d027-f1f7-420b-aacd-3331f60b3b73': 'Taco agreement kind',
#  '34a85334-a3d1-433e-8c8c-e6946a523918': 'Banh Mi other need',
#  '32b586d3-b661-4812-a839-d3aa7e94788b': 'Dumpling compare artist',
#  'dd44155b-1ea4-4505-a9a5-18bf94e9cb53': 'Taco seven performance',
#  'd5b7aa6c-808e-44a9-9848-32c005fa44d5': 'Rice order stage',
#  'ce70d6ea-97bf-4177-8d60-35da36be76cf': 'Dumpling author language',
#  'c9e9e017-379c-4551-b9dc-253b099d7c6c': 'Dumpling exist lose',
#  'c3b486f2-fdef-4568-8bc5-08cc4ddf6737': 'Taco property she',
#  '85b718bd-53c1-458d-8d41-ef4bd58cad37': 'Ice Cream rest then',
#  '859b89f4-bf8e-47cc-a7e4-64942eaa8234': 'Sandwich case control',
#  '6b4495b2-e992-43cc-8021-26b2684f6ec7': 'Takoyaki resource successful',
#  '67a1f939-b2c1-46e1-975f-eb2184ce8949': 'Burger green treatment',
#  '6077ad9d-56af-4da8-8e1d-cce20c9bb562': 'Taco could TV',
#  '41b3cfca-0b82-4509-a61f-7e0082daf39f': 'Ice Cream stock eight',
#  '40c65816-f1b9-42d3-9dd9-7f1f6d7c98f8': 'Pho road table',
#  '3fca12f3-55a1-4e57-9036-6eb8afa2052f': 'Pizza pick give',
#  '3f0f890f-8b30-4865-8767-5aa462298f13': 'Sandwich he friend',
#  'fce563d7-e90b-4998-a197-6faf9bcff8ca': 'Pizza lot share',
#  '998dce2c-adf6-4dc7-96f0-47837387bb1a': 'Burrito town drug',
#  '82df3bb0-409a-4563-b1f4-185266f7e05d': 'Banh Mi girl list',
#  '77b8beff-607a-4b9e-bd32-9ea610ae1dc9': 'Donut road positive',
#  '67fdef8d-a929-4cd9-9221-29972aca7d14': 'Takoyaki just try',
#  '3bf70e8f-48a9-48cc-977e-6f49b82593ef': 'Burger much ability',
#  '33b68ca7-0925-4780-9d9e-5b4ec47f94c3': 'Rice never simply',
#  '2d6d1b05-f4fb-4a7b-955c-4357853b1aa4': 'Cookie thus student',
#  'c1f3d7d1-6d94-40de-91da-7b80a253912b': 'Takoyaki son sure',
#  '728b517b-5c39-4c33-a3e9-d54b425b5c54': 'Takoyaki surface might',
#  'bc671320-dd2f-4472-b2ad-d483dd422450': 'Dumpling suggest service',
#  'b94d5bd2-1947-417a-9cda-cd8abe4f6156': 'Goi Cuon that drop',
#  '85b3005e-f429-43f9-abef-b93909a940fb': 'Hot Dog base against',
#  '7ccb4f93-e24b-4f1a-bcb5-d2537dad1433': 'Takoyaki of price',
#  '47e7aec7-62b5-4d95-b718-542247d18ff6': 'Burrito knowledge control',
#  '3fc8dcd3-db46-4f97-bc6a-2e0efb9bd799': 'Rice scientist treat',
#  '0dc7e0d9-14bf-4780-89bf-4f020fd4a4d2': 'Pasta heavy leader',
#  'bf4d1555-77e6-4881-a840-84f365e51398': 'Pasta bill responsibility',
#  'fef87462-afd8-4016-b5bd-0bd6711c8e96': 'Pasta not your',
#  '813fb03f-bb50-4a68-a758-f50f3177b57b': 'Pasta medical break',
#  '6aa25815-7f60-4d99-980f-896ce12de77d': 'Burrito quickly reveal',
#  '7e1bb966-ea55-4797-b53b-ab9ab81396f4': 'Pizza single half',
#  '3a3d0713-6d9e-47c4-94dd-ddd00bd4e17b': 'Burrito support ball',
#  '02431fe9-d3c8-4a86-9cda-9fa6e64d5a84': 'Burrito understand education',
#  'e4576899-48d1-4b61-a0b2-2913e6c0204d': 'Sandwich television model',
#  'ba808943-bfe3-43fc-a816-33e85ab8abd6': 'Salad inside series',
#  '9e61b59a-efda-4eb1-81b4-deebb2e1d5ce': 'Donut under add',
#  'e8a994d5-2176-458b-b425-f223f7b270c1': 'Takoyaki chance person',
#  'a5820c02-c370-4a04-95b8-0708590ea3e5': 'Pudding give health',
#  '47238fad-b80e-41de-8f09-138c85da8423': 'Burger building only',
#  'e58a2039-c8b8-4a7c-821f-dbc09edb27d6': 'Takoyaki too movement',
#  'b4a413c4-0d59-4871-a826-87414232238b': 'Pho quality cultural',
#  'b4167ee0-3b7c-4be2-9f3f-ccf67e268800': 'Hot Dog give person',
#  'b38c20f6-919a-45f5-b7d4-9d6c97459491': 'Rice indeed conference',
#  '7840b9f9-4651-48e4-b2c4-7b1648b9a791': 'Pizza sound everything',
#  '5d169073-d1ec-4367-b3f0-e6b419ef64aa': 'Takoyaki one relationship',
#  '4e768567-0830-4cac-a1ff-d27476ebc9a0': 'Ice Cream high all',
#  '2f2c5097-4428-46e8-9e77-42ac07338074': 'Goi Cuon to economy',
#  '095d3a80-a3eb-483b-b4da-30771c0a7eec': 'Taco why benefit',
#  'e2e9f4de-3ae4-4071-a5c9-782327260b41': 'Donut rest anyone',
#  'c7378cc8-0095-47ac-b879-d48e7c057b3c': 'Banh Mi group matter',
#  'c508322f-1955-44b3-87b6-eba8d9cdfafd': 'Goi Cuon history responsibility',
#  'bcce404e-1c62-4cb1-952b-0892f77230cb': 'Cookie argue section',
#  '99fe1268-71d8-4de0-bcc1-c2a8cfb96b03': 'Pho lead voice',
#  '8e446a05-41b4-447e-85af-0cdc388f616c': 'Burger staff policy',
#  '6e7247ca-2d1d-4cb7-9b9f-044cec0dd917': 'Taco leave why',
#  '44037d0d-5225-48c6-9768-3149d14ceb18': 'Rice represent enter',
#  '162404e7-7521-4cf7-a8ed-9ff331071c48': 'Burger college despite',
#  '14cd7d7b-a2bc-4f91-a795-1bd237582971': 'Hot Dog economic seem',
#  '0be9316b-dc9a-4f4c-ab12-3912160b31df': 'Salad scientist office',
#  '0e10c274-8609-4beb-97eb-bde238f22da3': 'Hot Dog station only',
#  '09cd6145-3748-410b-ac98-8f41ab723edb': 'Ice Cream student between',
#  '017d908b-1ea7-4356-bd9d-920ab0eb736f': 'Pho color forward',
#  'f0de584f-89da-4e70-8f0f-ce769e7403d0': 'Salad thus bring',
#  'd564c6f6-4df7-4f8c-9e6f-6692659ec2e0': 'Cookie big sell',
#  'd4977e9e-ad75-4ee2-a4f3-290216d40d63': 'Pho next safe',
#  '9fe9eee6-460d-4d27-96e6-77b5ae8bd752': 'Donut north machine',
#  '97f1c526-904d-4266-993b-dd123ff629bc': 'Pizza now force',
#  '1660b698-6a45-47a8-8bcd-ffb55e63eb09': 'Pasta character wind',
#  'f079f18d-4bfe-4006-b4fd-9de4c2ccf4b1': 'Dumpling brother box',
#  'aaf3ce4e-f678-4291-81d8-a11100ae0643': 'Dumpling Mrs pretty',
#  '8cefd9ef-cf44-4dbb-9c53-c09fec4575dd': 'Salad today a',
#  '62d9d45c-776b-4461-826b-41657131db0a': 'Cookie focus professional',
#  '5ee55bd4-ff53-407b-a1a3-1c77b8adab8c': 'Pasta have environmental',
#  '571cb673-b654-4e11-89c6-1140abc532bc': 'Hot Dog home garden',
#  '4c0dd0d2-8b00-4515-95e2-7e4c03f74f80': 'Pho news kitchen',
#  '494ca756-d4b2-4e7b-82f5-19c3b361f336': 'Taco soldier threat',
#  '2be57e67-c975-416d-994f-8032c045dd6e': 'Rice book role',
#  '228d5b2c-1c99-4fcc-b346-886ae2b16d4b': 'Hot Dog act road',
#  'fec0b0c5-2f43-41d6-8c8d-4ce54f3fc8d2': 'Rice time commercial',
#  'd6d5b279-bb4d-4394-bd33-a2e40a51a0b7': 'Banh Mi draw clearly',
#  'befa30ea-9522-4d78-87d9-da9774f7acb6': 'Dumpling treatment middle',
#  'b27d80d7-6501-4ad7-82bc-e17c86c92b5c': 'Dumpling offer finish',
#  'a13df869-b07a-4968-8aa3-421a652f1214': 'Pho common shoulder',
#  'a045ff83-1808-4f36-8b6a-daeb3403f567': 'Rice art radio',
#  '7ee3effe-ad9a-496c-bb46-0f028cd88e4c': 'Hot Dog behavior life',
#  '7cb3bb79-0c84-44a7-81db-97722cfba52d': 'Sandwich relationship main',
#  '75d2707f-514b-4573-980d-86c780b8515b': 'Donut bill thought',
#  '2804b787-526b-45ca-aeb2-af7e0b484f9c': 'Pho discuss red',
#  'e4aa0fd0-b4ec-462e-88ce-c5fedd4ce212': 'Burger including head',
#  'd78cf45c-947e-43ed-827a-82a2c6b4ae37': 'Pasta certain but',
#  'd42cac26-5758-429e-9cdb-69f7d37b92a4': 'Goi Cuon memory budget',
#  'c2ef9b98-913a-4118-8b12-e9c4df99b1a1': 'Ice Cream look my',
#  'a2a7803f-89a7-406e-9580-70b9781c5f88': 'Hot Dog hair matter',
#  '9d56500b-936d-4940-8097-947e325f0ec8': 'Burrito account guy',
#  '69c2f427-7d06-48dd-9d8e-b2430c0d706c': 'Sandwich reflect process',
#  '638edd36-1300-4060-acef-72c928b3704f': 'Dumpling black appear',
#  '56260b6a-ff4b-49d6-a8b7-b5460abe4e23': 'Salad will those',
#  '5d13aa9d-409a-40db-8b54-532fc00d3e09': 'Pudding time debate',
#  '2d037c9c-dc75-4408-a6ad-a152eb62c677': 'Pudding why western',
#  '16309098-a517-4e4a-bd25-0e25b5d2b711': 'Rice discussion major',
#  'a584b1b3-e0ee-4bb4-8da2-1a114eaacd99': 'Pudding turn similar',
#  '9aa081b9-9d94-4a95-b3cf-d296b11a2c6e': 'Pho discussion office',
#  '9ebf4de7-137e-46a2-bf72-c01ac9bad90c': 'Pudding mind hold',
#  '94e9e7ac-fb4d-4e7b-875d-d02d336468fc': 'Burger prepare form',
#  '7e5fcc72-a7f2-47fd-90ec-005c8757139d': 'Goi Cuon factor like',
#  '70a6d6f8-01ff-4ab2-b409-0797c9ae9547': 'Goi Cuon easy cultural',
#  '6f068678-d37b-4a53-9914-000b21d8f09d': 'Goi Cuon visit policy',
#  '64f4850a-5fce-4945-b6af-d59d5209b5af': 'Banh Mi certain here',
#  '63719ed6-3e27-48ae-99a5-3ddfd016b178': 'Pho only city',
#  '40ebc892-0b3b-44c2-abae-3597a710ca82': 'Taco this walk',
#  '27f5dc51-d5e0-41c0-bd2e-86ce7a86e520': 'Pasta claim body',
#  '2ee6089b-b957-43be-aec9-f4d8718a42a5': 'Pasta camera heavy',
#  '12c8a255-af5a-4341-8100-85328ddf4459': 'Cookie yes reveal',
#  '0e50a01c-a0e5-45d8-8db8-97d037c50249': 'Hot Dog matter indicate',
#  '08f2c838-63e3-4d8b-ae57-1582120861d6': 'Salad decide age',
#  '61ee9426-df15-4a89-9bdc-705a648f081b': 'Hot Dog seek whatever',
#  'd64c510a-70fc-4458-a68e-36e40a3ce3b9': 'Pho heavy billion',
#  'ae9bf0c6-ec4f-47ac-8a0f-66dfb4dfe1f2': 'Burger international surface',
#  'acaa12e5-6a8b-4547-b4cf-ecf8c8c6944c': 'Pho talk by',
#  'a5f22067-ea78-45b6-b08e-1c8e7832c387': 'Pasta east poor',
#  '7394162d-aa20-4dc3-b027-bddb1631e1f4': 'Burrito between develop',
#  '59777c0c-3817-4102-b1f3-6bf5d8765ead': 'Goi Cuon business never',
#  '453a0268-c21d-4233-802a-5e8a4c0534bb': 'Donut defense effort',
#  '3ca9341c-a2e6-4dc0-80e4-d2e93bdb6377': 'Pasta fall claim',
#  '2bb9ed60-f489-4188-ba49-c3c143e02a73': 'Takoyaki pull son',
#  '19ee0339-b840-465c-9330-d190cc301a2f': 'Banh Mi price listen',
#  '125bf761-c9fe-4f9b-adcc-995d9ff527d2': 'Banh Mi business attack',
#  '02f3acf3-a9ce-4578-9379-23f6f426d845': 'Hot Dog song discover',
#  'ab9b954f-d107-441c-859d-16be168083ce': 'Donut break hair',
#  '43f3c0e0-2b7a-4f27-ba86-0aff3c4d161b': 'Pizza movie let',
#  '36fc4c04-ee12-419f-a166-16474d650b0d': 'Ice Cream herself protect',
#  '2f9b5879-588f-4059-9336-3e76e2d0dff0': 'Pasta mission training',
#  'ec0aed20-f74a-4ed7-9251-2ec1ab45872d': 'Taco memory red',
#  'e7584f5d-cce0-41c4-bdd0-c0d9f2afa792': 'Pudding break personal',
#  'ab1f8818-cce4-48eb-a300-eba4b8cbd1ec': 'Donut that call',
#  'a0e828c8-6465-4589-87e0-cdd234907b74': 'Hot Dog television put',
#  '99d5762a-5d97-428f-901a-34ac93505907': 'Burger full good',
#  '67ab3064-ba33-4856-a4ad-ec248ab003b6': 'Hot Dog civil civil',
#  '549bee17-ec9a-4034-9b84-09e3ccc9800b': 'Banh Mi reach quickly',
#  '507414b4-348f-4978-9361-d197c025ed37': 'Ice Cream during nor',
#  '4b91b7d4-e431-4053-aae0-97c690d5a3b2': 'Taco area check',
# ...
#  'd514fca5-5c94-435f-b5c6-01d9cd50da27': 'Pasta many they',
#  'bfab1c62-c01e-4a3d-b067-073af2eb8d58': 'Pudding like mention',
#  'bc9c431a-2dae-4bda-a0ee-2bac74ffc88a': 'Pho deep wide',
#  'a7ddaa0e-d059-4a99-b045-225c0b4800a7': 'Sandwich somebody think',
#  '9f0a726d-f6d3-4476-9586-da82ff8b4ddb': 'Hot Dog perform above',
#  '92052f78-6a92-45f2-85c2-ec621560fff3': 'Takoyaki TV spend',
#  '90225082-0dfa-4cc2-917c-1df200139a28': 'Donut condition seven',
#  '38e45cde-4892-47aa-970c-6038d5cbd0d7': 'Taco goal then',
#  'db481bfb-37d9-4134-a774-a1c82986d58f': 'Taco such skill',
#  'd12c514f-e3c0-49c7-b923-59a9d3d81c92': 'Dumpling interest glass',
#  'd0b4ac2d-5cb4-4a42-81f2-038ab1254d42': 'Sandwich toward lose',
#  'c2a61c9e-e6a8-4fe5-a3ba-edb94f2005eb': 'Pasta son reflect',
#  'b5aa6315-ae80-478c-85ff-571974e5d7c7': 'Donut performance suddenly',
#  'ab185f68-39f8-480b-a6b2-f5997d56ff93': 'Takoyaki report popular',
#  '92256570-e92f-4ed5-8dcc-2e7b9e2ca222': 'Ice Cream thus a',
#  '814aa520-5103-4e3b-9293-0e5066b1486c': 'Goi Cuon every remain',
#  '810a4ca1-2fb2-4fc6-acd4-3ee3ec114b46': 'Burrito kid response',
#  '429f2f18-7a4c-4e1c-9b41-f2832122a2ba': 'Dumpling medical American',
#  '40a68000-4ebb-462b-966f-468577a44120': 'Burger trip help',
#  '3319e8a5-5c5e-4c0b-8dd7-e449634fa0b4': 'Taco finish Republican',
#  '2fd05340-70eb-4fb2-9054-b60d9d249db6': 'Goi Cuon art stock',
#  '07a4ade7-5003-4cbd-a570-093a7742194f': 'Donut scientist deep',
#  'edbd806a-73a6-4ba8-963b-748546826d8d': 'Dumpling event challenge',
#  'cf0af255-16a7-44ac-a148-900913d2a2a2': 'Rice would voice',
#  'a79b3591-e662-4bfb-bbac-46248b06a1d5': 'Pasta week whole',
#  '993234aa-7886-4c37-923a-ebe76b3ccb37': 'Salad worker everything',
#  '975e6869-1177-473d-865e-9fa2cf7ccc97': 'Salad finish may',
#  '47368fc9-f85d-49bc-8a29-3aa84d27d516': 'Cookie response begin',
#  '1d6913ac-204e-44d6-942f-e709419ba4c4': 'Pudding artist phone',
#  '09734088-bb92-42c6-acbe-1777bcc537cc': 'Pudding positive she',
#  '508a27d9-26c5-4299-9cb0-22f99fe05737': 'Sandwich by worry',
#  '451a8a9e-4ce3-4731-acbf-a72be28bbd26': 'Salad grow state',
#  'e3fbd993-8d9e-4bb3-815f-78f262f62b09': 'Rice garden arm',
#  'd50e314b-797a-42c6-8853-937873d68ae7': 'Donut amount society',
#  'bdf23c7c-60b0-4380-8b39-48b45d17dd7f': 'Pudding with economy',
#  'a21f84ce-4044-400b-88fc-14f7c5683c98': 'Pudding herself item',
#  '45ad774f-f044-4333-b190-52bcd98df26c': 'Pho carry TV',
#  '1c3c3a29-4b4e-441f-8fb3-04f53544c00b': 'Donut nation doctor',
#  '02874d85-4c6d-4991-920f-e1e457450a2e': 'Dumpling key policy',
#  'f3062fe4-e6f3-44b5-bb66-3eb62c279e18': 'Ice Cream tough again',
#  'cc84eae6-9641-42b5-bb83-32d0fb3c9b4a': 'Pizza difference break',
#  '9b811070-fcb3-4a77-a714-7d264806dcdd': 'Pasta wife one',
#  '80c67c0e-a57b-4a4f-89fb-a82a97333639': 'Dumpling enough leg',
#  '7bf63ee0-6035-4025-b8a0-cbb1436300d5': 'Sandwich sign whom',
#  '73921730-9d26-467c-b39f-1c9e32598417': 'Burger lay evening',
#  '5f3953e0-146e-4e2e-94ea-27faca1fc971': 'Donut discuss serious',
#  'c8aae29b-e60d-4161-a37b-1d5048008595': 'Takoyaki where sell',
#  '9b769621-24bf-4b04-bf55-878916ec5b00': 'Pho near on',
#  '87da59c8-8da5-46d1-a487-d9771b381531': 'Pasta remember fact',
#  '7efa7eda-106a-4763-863a-0cb911e08749': 'Dumpling treat whether',
#  '720f6751-be4a-4838-ae63-0b8567d4fa65': 'Cookie dinner place',
#  '5fc9f5fa-32f2-4abc-b98a-79ae561194d2': 'Banh Mi mission quite',
#  '53cb96f4-bf77-4784-a099-44021b0a56cf': 'Goi Cuon the of',
#  '4d1d3459-25bc-4f5f-aaca-84d9ca9e5df0': 'Pho two point',
#  '2a2d59d4-4f30-4282-80f4-dad054446648': 'Banh Mi happen skin',
#  '05838384-9130-4437-84b1-8de1c83c3982': 'Ice Cream class source',
#  'f70cacdc-c83d-4246-bbc1-8adff21f6590': 'Pho a financial',
#  'bbc67d69-a3c9-4e69-8796-87d1cbfe3b4d': 'Sandwich cell later',
#  '9553bd98-9845-48d9-ba2f-e6aac029b224': 'Rice guy present',
#  '8f88f52b-7992-4301-a4c3-0c4ad3a14b64': 'Banh Mi economy pay',
#  '8d663f75-9dad-4656-b697-1ea23a92c4f5': 'Pasta do because',
#  '57860c93-7e37-4ad3-8aa0-9df18597e3be': 'Salad weight artist',
#  '5825a350-762b-4baf-9d31-51d576d3a5db': 'Goi Cuon successful each',
#  '40d159bd-2bb1-49cb-a5df-4be89eebb816': 'Pizza hair Mr',
#  '2fffd8cd-634c-4842-bc22-7c0b4c4145d8': 'Donut tend station',
#  '2e8530fd-3dd4-4f4f-a770-badd79920140': 'Takoyaki on above',
#  '212dbe55-b03f-4236-b167-84abe6be8237': 'Banh Mi age because',
#  '06687d37-68f5-436e-b850-c4f3b554b41f': 'Salad compare meeting',
#  '902c77b3-e4cd-4906-b889-193cb63a27a3': 'Goi Cuon bag officer',
#  '5d8d43f9-1be7-45ae-ac50-85fec85d8505': 'Goi Cuon state world',
#  'fc76cbcf-72fb-4c1b-b5b5-87afcc1c83d0': 'Pizza peace say',
#  'e45e2af0-f8c9-42a4-9534-6e3824cd4169': 'Taco school yeah',
#  'e2ddfba9-98b8-4678-9014-a71b51e251c2': 'Salad left he',
#  'db7b1756-b1ce-483f-af07-77cd93cc25e6': 'Goi Cuon perhaps your',
#  'c9d80c79-00a1-441d-ae98-be04b1d6883b': 'Burger treatment physical',
#  'c360fc26-6c40-48db-bb87-bf99559d599e': 'Pizza behavior last',
#  'bc91a26d-4503-411b-9a1d-7518a298012f': 'Ice Cream establish me',
#  'aec8bab2-4eb6-45c4-9ca4-8e4a7f6872ab': 'Goi Cuon small interest',
#  '9c1b1cfc-993e-4f09-b50b-8518599de3c6': 'Burger special on',
#  '9b258a65-9f4a-4f9e-8589-7bc313331482': 'Pho seat experience',
#  '91693fad-84cb-4584-ae1e-066b04956b9e': 'Goi Cuon modern baby',
#  '84ea0a05-3179-497e-9d1b-3f1589bc9196': 'Banh Mi near company',
#  '78232228-805b-4880-8c82-3670595a55cf': 'Takoyaki represent capital',
#  '3a99a0a9-e0f5-45ab-ab18-084377cfbedb': 'Takoyaki practice onto',
#  '0fb06b99-ce36-4fc7-af95-24177cbff9b5': 'Sandwich sort trouble',
#  'e55f5fa6-094b-428f-9337-ee1b8f634875': 'Burger fill letter',
#  'd967bbbb-d62a-4483-95ca-877e2edafacf': 'Banh Mi there win',
#  'c86067bc-2f0a-475c-b434-9ecad420c101': 'Sandwich available speech',
#  '89d6e768-d64d-4ef7-8e9d-1ec09a6401a8': 'Sandwich spend as',
#  '8383dbe1-883f-4e19-ae46-949d15752c9b': 'Pho military town',
#  '6face8aa-79d3-48bf-b1df-490e93b03cfd': 'Sandwich red name',
#  '37f3e7eb-d610-43d8-abce-9e7ad538bfe1': 'Sandwich three thus',
#  '2c68b972-f551-4d6d-988b-26a442cadd8f': 'Donut into plant',
#  'fe2d6941-1c9d-4bf8-a541-a185cac13f9f': 'Pasta need top',
#  'e286e1f5-301f-42a7-b0fa-0e1cd0c62764': 'Pizza step price',
#  'e2439e84-70d0-4992-802e-d5d1ce59cc18': 'Sandwich sister scene',
#  'df71517e-d64f-4893-931a-6d9274f25b99': 'Cookie agency foot',
#  'd8616967-2cb7-48a2-9619-2fa277f14947': 'Cookie around that',
#  'aeef0f6e-b1bd-4be5-be68-c4974d1719ed': 'Salad cultural name',
#  '6ba8a751-1ea1-47c2-abf1-9c28e53117bb': 'Rice affect push',
#  '619dc77c-0ce4-4f05-89dc-21018b5b94a5': 'Salad recent ask',
#  '5462ef9b-27c9-4e67-bf0b-6eda30b51770': 'Cookie trip early',
#  '4b27689b-b95a-4c40-aadf-d3c32e9f8178': 'Pho eat phone',
#  '076e80d9-76fb-4931-aa3c-aa2f81dca20e': 'Donut claim improve',
#  '06b8f169-6ad0-49ac-bbeb-38a77c258c62': 'Goi Cuon share remain',
#  'f7e51a6c-abdf-45a4-a288-649afd5a15d3': 'Sandwich at voice',
#  'd401ece6-1fa0-43ed-962c-17d15b8c9ede': 'Ice Cream four number',
#  'c059c000-38f1-4cf0-94d9-88902ae954f7': 'Taco employee foot',
#  'b21a1459-1061-434c-b2fe-8ea57c1b1e6e': 'Sandwich final child',
#  '8abfcd95-9e9e-41eb-a68e-09a95d1d9b26': 'Hot Dog discuss hotel',
#  '5e4e46df-36a2-40ee-9ec7-9072e67df981': 'Hot Dog interview answer',
#  '58c5ef9b-7055-47e9-b9e6-b52f2b8deabf': 'Pudding simply state',
#  '4acb26ba-52dc-4d16-96f2-34caf61cc389': 'Cookie stand left',
#  '31d930b5-abf6-4fde-90a5-bf91fb8699ce': 'Taco yet your',
#  '1e3c681d-50c3-49f1-87a4-e14dfd14f9d0': 'Rice teach threat',
#  '12af5a4c-0edf-4e8e-bb3e-7dc23c070dba': 'Goi Cuon newspaper live',
#  '046212d5-f660-424d-97f1-34355291302d': 'Dumpling dog local',
#  'b7a815eb-9cbb-4c18-a33c-88ed060edfb5': 'Rice assume international',
#  'af3bc942-c79c-4a6f-9de7-a93e184a3f20': 'Pho player go',
#  '87de0756-3e9d-4d00-bc68-a9dc7df40877': 'Pho seem will',
#  '1c672e07-bf8a-465b-a69a-0e6c7479d159': 'Ice Cream piece manage',
#  '03c431f5-a9a1-47ac-858c-863458ae5340': 'Takoyaki contain blue',
#  '602118b5-fe74-4dc2-9c2d-a595aff83f83': 'Donut create little',
#  'bfa2b5dc-246d-4d46-8869-98a910782672': 'Cookie without wrong',
#  'b2282cb5-e4b0-4187-a005-58e645ea361b': 'Hot Dog court nice',
#  '94ee7d82-11e8-465d-8a14-6077d5244bc1': 'Donut drive executive',
#  '57940c14-1a6d-4652-8d6b-2f783cc50fc7': 'Pizza wish force',
#  '4fa98a09-383b-4946-ab75-b292da4c8372': 'Sandwich dream agreement',
#  '4eae6c3f-ab16-4afa-b66f-6c7d3da92213': 'Pizza base fly',
#  '387ee007-068b-47fe-b048-107cf8392828': 'Goi Cuon resource film',
#  '288bc7ff-2e5e-4696-8f5b-9c7efdd330e3': 'Goi Cuon consumer market',
#  '2081d0b6-0d6a-4683-8058-f3efbc4740e2': 'Cookie agent describe',
#  '14cbb34f-d039-442d-82ac-ef1ac640b11c': 'Banh Mi spring sit',
#  'c9132ff9-acd0-46b0-a5ca-cfe751e40f92': 'Rice attorney shoulder',
#  'bd46abfd-e1e2-429f-895e-434573062348': 'Pasta time official',
#  '8ff7bf14-8145-4b79-a34b-ade32abac161': 'Burrito figure walk',
#  '86d9fbf7-c758-4608-b9d2-619c1232af56': 'Sandwich exist by',
#  '73af482f-f9fb-4e92-be68-3e4caf799bff': 'Taco myself serious',
#  '6cc01406-882a-414b-a634-3821ddd8cd98': 'Takoyaki treatment accept',
#  '3ca0bd0b-f525-4435-856b-b71179e3a183': 'Pasta pay city',
#  '1dd39b7d-9c21-4eea-962e-66667c5f2278': 'Sandwich much really',
#  '182635aa-fe99-4fe5-9366-3c447a2a1241': 'Goi Cuon role reach',
#  '144c985a-ace3-462a-86ac-8d2f8376573e': 'Rice view doctor',
#  'ea43a7b8-42eb-43d4-a26a-71f7c2c38bc9': 'Taco raise these',
#  'd4e583e1-d0df-4f48-b933-8fa1abb9384d': 'Takoyaki ask our',
#  'a5fd8a13-aa23-4730-827d-46eed4b039a2': 'Cookie hour call',
#  '99830724-a41b-4441-9f83-da113226a9e4': 'Cookie win seek',
#  'efc83bde-097e-4dc5-b92f-13114bc7af00': 'Pasta school certain',
#  'c2682bdd-98cb-4c62-8b83-1b2e2f538e31': 'Taco bed government',
#  'af00b633-2817-42d5-907d-6d47d259c7cc': 'Banh Mi important bit',
#  '9c598c5d-fe6d-45dc-9836-047701fa00a1': 'Cookie cultural later',
#  '728b98fc-f012-4b18-8f13-6f7c34fc0fa6': 'Dumpling exist far',
#  '276ce56e-f318-4eb7-a73e-9890dfeda559': 'Pudding lawyer different',
#  '16417f95-1877-4aac-b65e-cb81a68b6989': 'Burrito hair box',
#  'eef16296-4a4d-4d93-8aac-befd81fb1963': 'Pudding work interesting',
#  'ee7d9fc1-45e6-4f1f-b024-e577f08d18e8': 'Donut eight democratic',
#  'ec0b27e4-b825-4236-a2d5-5c87a35b3e72': 'Salad several green',
#  'e65677d0-4507-446b-b060-f7cabc5c4483': 'Taco on lot',
#  'ac9febd2-4546-4ab2-a829-8ae6d74b1a51': 'Burrito audience true',
#  'a80bc96f-0341-442e-9c0c-59475a538f91': 'Pho condition after',
#  '8e9d02b5-60ff-47d5-a967-587bb3aa5b0d': 'Rice radio less',
#  '84c22f33-ca4f-4d32-9c5f-1fc0e940a683': 'Taco ok early',
#  '84a57345-87a4-4456-a56c-28c67ab3df41': 'Takoyaki parent less',
#  '64318522-b334-40f1-b7fc-7aad813dc15d': 'Goi Cuon see rock',
#  '3f9ed6ba-8d9c-4012-8c9f-6e8ed555c9b9': 'Sandwich indicate manager',
#  '38d006a6-c544-48ad-bcb9-d5eb5e87cf9b': 'Ice Cream own garden',
#  'fc8855f2-7fdc-4e50-a34e-14f7b5794513': 'Rice realize a',
#  'e7e785d7-01f0-4416-b254-21c7879b7e9e': 'Cookie trade exactly',
#  'bad8b0f5-b89b-4881-bb08-ad8a325e88c4': 'Banh Mi she station',
#  '859699ba-7d24-440e-8e42-35efba5b8dd7': 'Pudding when in',
#  '7f8251ca-1582-4faf-b486-1f29af1723a7': 'Dumpling here east',
#  '84552088-67c0-422e-a08d-2c0340390a99': 'Hot Dog central for',
#  '5e084fec-ef58-4931-a0e6-df0c183c70d5': 'Taco exactly sure',
#  '4fe9371e-29f2-48cb-b7f7-7496d927b051': 'Rice none argue',
#  '4e86eca8-5c4d-487a-b278-92f23d21ef8d': 'Cookie discover answer',
#  '1e5ea0f7-d2d5-4190-8539-4d3a4a09ff4e': 'Taco social concern',
#  '1ba15a00-0079-4b8e-b853-c0f70b3c9662': 'Pho history simply',
#  'fec1185a-0a0c-46ad-8b6f-63e70cab8907': 'Takoyaki read wrong',
#  'e3dbd203-22d2-436c-af68-e70e483e42a0': 'Rice pretty kind',
#  'c4aa297c-ce53-4309-957b-3ea287d4ff1f': 'Sandwich approach store',
#  '72a8f644-c989-49d2-85d0-f3716ad2dbe6': 'Ice Cream item culture',
#  '59fc678b-240c-41bb-95f4-903f91de8497': 'Pho give Mrs',
#  'ff82bc14-a4c1-4215-a5ec-b7c175c0e9b7': 'Rice people name',
#  'f33d194c-6175-41f0-8a5c-152e0fe5455f': 'Goi Cuon also interview',
#  'c878c628-f3e7-4d31-a3db-a24dc86297f7': 'Pasta own theory',
#  'c8494451-aab8-4ce8-9d66-1a42098aef25': 'Hot Dog street task',
#  'a77308fb-f3fa-4cc1-b69e-f5af4da026a9': 'Cookie garden he',
#  '9b6d6eee-b425-48f1-98b7-48be60978832': 'Salad he respond',
#  '917d76e1-27ba-4372-8d0e-3a312d9ea7b2': 'Salad campaign near',
#  '7657d0c8-4e9c-4342-ab79-5467163210eb': 'Rice worker spend',
#  '73f829c8-7cee-4d88-89a2-e0ea119b1b4c': 'Sandwich sign people',
#  '39db7bdd-2b2d-49c6-9872-31c5f860ab41': 'Rice together organization',
#  '0c34978f-c41f-4ec5-9886-c7df06dbcba2': 'Salad area service',
#  'e3478b3e-e512-42dc-a10e-5f7f9a923529': 'Burrito argue behavior',
#  '327be443-0039-4f38-8ad6-7ec5e00a089c': 'Cookie detail political',
#  'e1f7ef60-5932-4b91-9022-8ba88855eb6b': 'Rice read middle',
#  'd0604c70-9682-4844-a8a3-6b023ef7e3a9': 'Pho often cause',
#  '96401878-f516-45ca-8f86-94435dd616f1': 'Donut away movement',
#  '8b07f891-41a1-43fa-a489-a7b527e4514b': 'Goi Cuon baby remain',
#  '80abdf2e-2775-4f96-a529-066c3191d894': 'Burger store tell',
#  '650f9939-4992-4287-970a-e1d332d1d69b': 'Hot Dog method wall',
#  '50475d62-409e-472d-8b18-4cdd25a505fa': 'Pizza break network',
#  '25794005-1c8f-42d4-88c8-d99550970c01': 'Burger long worry',
#  '0f8bdbf2-8674-4e9b-925c-5a1cc0dff90e': 'Ice Cream within attack',
#  'ce7cf10f-76bb-4e27-9e61-aee9469b6bd1': 'Banh Mi image tell',
#  '9db1d9bf-72fe-44cb-88ef-d236f1ba4396': 'Dumpling natural peace',
#  '7afb54ef-1a48-4828-a4a0-46cd400a233d': 'Donut wonder lay',
#  'fc1cb777-d236-403f-a19f-47fc05f024d4': 'Cookie interest billion',
#  'fa640ba2-ffc8-417a-8a3c-1468b36539af': 'Burger ball later',
#  'eed402fb-ebb2-4343-a646-9b9feb36c825': 'Cookie though able',
#  'c810efd0-a1fb-4fd3-b3ed-47e7a26dfc93': 'Pasta smile either',
#  '7f43ffef-9b27-4296-83f7-a64e1166f78b': 'Goi Cuon stage rest',
#  '7d3d29b1-071a-48cc-b3d8-26515b285ebe': 'Sandwich hold response',
#  '73e4a232-d886-45a0-94ca-057fdf55de9c': 'Burrito someone adult',
#  '5842607a-b6ad-4ac5-bdaf-7ad3e4e856ba': 'Takoyaki board military',
#  '0f5ea725-028e-4b0a-9250-51291a58dc03': 'Salad which few',
#  '87f73aec-98d2-4357-a81f-d05d457fa4c8': 'Banh Mi data always',
#  '0557e939-71bf-4c38-a3fb-d20c2528166a': 'Burger interview live',
#  'da44a9d5-8867-49a9-b921-7e30637d7901': 'Goi Cuon involve money',
#  'c149fe78-f2fe-41f5-bfde-1d007275d47a': 'Rice game some',
#  'bd998718-6b0b-4319-a271-27e01f24227c': 'Sandwich though force',
#  '6e677447-14e7-4b33-8173-e8ebc116205f': 'Taco federal rise',
#  '20da2ae0-8506-41fd-a084-cb51c75f37bf': 'Cookie thus subject',
#  'dae0b3b6-dfdf-45ff-8883-8513a4ddd4c3': 'Pho attention want',
#  '76a07693-d9c4-4f21-b08d-a938160f3b29': 'Burger throughout by',
#  '4a72ce97-ac5f-477e-981e-b12ef9d68c8f': 'Banh Mi might relate',
#  '3be08631-942c-4bb4-8c29-aca5723412f1': 'Pho worker improve',
#  '390e3dcf-242c-47da-912a-1707f3351fae': 'Pudding others heart',
#  '24c3c93e-554b-467a-9537-e679ed1a5666': 'Donut cup certain',
#  '16e25107-1082-4b17-94c4-536253a3a829': 'Sandwich draw sometimes',
#  '0324d3dd-1cfb-4553-9b24-66bf8d66bafc': 'Dumpling purpose rock',
#  '6f4f5a61-ea6f-4fcc-8f24-bfd58b746bd4': 'Dumpling develop experience',
#  '6ab7f1b8-4799-4d98-9188-b08be3301bb6': 'Salad performance son',
#  '64b670b4-afc2-424f-a2ef-7022bf7ee434': 'Cookie something fish',
#  '4f94457f-e897-4b8d-8306-5561236424f0': 'Pizza while turn',
#  'f5420bdd-33f1-4c82-8342-e4fb4cdf0200': 'Burrito environmental consider',
#  '7440fd9f-0f89-409f-a188-6d7b04684019': 'Rice Democrat laugh',
#  'e34d5b23-d584-484e-a194-7fb9c2c64f67': 'Salad be policy',
#  'ce855d33-042a-4f73-b2bf-15e126327dd2': 'Pizza whom where',
#  '71beee45-738d-4c07-967e-247679a4d3bb': 'Sandwich its both',
#  '1b7e38e1-d9c8-4b85-8fc0-b2807aa4ce21': 'Burger election success',
#  'fb04dc3c-8f3d-4f7b-a3d8-592deed779a2': 'Banh Mi both member',
#  'f3142224-cf20-4160-9faf-002eba2c38ea': 'Dumpling message rise',
#  'c5f3487f-c0bd-4564-80c1-b92f35c0b91b': 'Burger in recently',
#  '954cd42e-15f3-4bf2-8aaa-8237b2cccb00': 'Burrito successful newspaper',
#  '341a4470-c7d3-49de-a58e-b9d35f0a34cd': 'Burger down under',
#  '19bc87ac-dab0-430a-ae80-28bfcfd79f8a': 'Rice whether personal',
#  'dd4a7c8b-f140-490d-a543-42d2fa6cee9f': 'Ice Cream challenge morning',
#  '66eebd84-70d8-44e3-a7d2-6c2ac371b25b': 'Salad happy before',
#  '3278eb4d-0880-48cf-a6f4-50539fe761ab': 'Takoyaki behavior leader',
#  ...}

# %%
dish_user_review_df.loc[dish_user_review_df['dish_name']  ==  'Cookie thank particularly']
# Out:
# Empty DataFrame
# Columns: [user_name, user, rating, order, dish, dish_name]
# Index: []

# %%
def find_similar_dishes(dish_id=None, dish_name=None, k=5):
    try:
        if dish_id is None and dish_name is None:
            raise ValueError("Must provide either dish_id or dish_name")
        
        if dish_id is None:
            dish_id = dish_names_inv.get(dish_name)
            if dish_id is None:
                raise KeyError(f"Dish name '{dish_name}' not found")
            
        dish_id = str(dish_id)
        dish_ind = dish_mapper[dish_id]
        dish_vec = X[dish_ind].reshape(1, -1)
        
        neighbor_indices = model.kneighbors(dish_vec, 
                                            return_distance=False).flatten()
        
        neighbor_indices = neighbor_indices[1:]
        similar_dishes = []

        print(f"Since you eat ----- {dish_name if dish_name else dish_names[dish_id]} -- {dish_id}:")

        for idx in neighbor_indices:
            dish_id = dish_inv_mapper[idx]
            dish_name = dish_names[dish_id]
            similar_dishes.append((dish_name, dish_id))
        
        return similar_dishes
        
    except Exception as e:
        print(f"Error finding similar dishes: {str(e)}")
        return []

# %%
import random

name_ = random.choice(list(dish_names_inv.keys()))
find_similar_dishes(dish_name=name_)
# Out:
# Since you eat ----- Burger at would -- 6b5b403a-b5ea-4548-8565-262382ddd41f:
# [('Pudding try include', 'ac4ebf8d-ad35-4c4e-8544-069825ba9390'),
#  ('Pho history simply', '1ba15a00-0079-4b8e-b853-c0f70b3c9662'),
#  ('Banh Mi skin life', '2045b73b-bd74-4448-9768-273df608da28'),
#  ('Banh Mi three able', '229d62b9-e622-4c4a-b4e6-aca52d07be21')]
